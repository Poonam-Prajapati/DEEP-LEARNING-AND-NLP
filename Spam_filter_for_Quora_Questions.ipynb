# %% [markdown]
# # Things to do:
#     1. Get the data
#     2. Import the packages
#     3. Read the Data
#     4. Split the data
#     5. Clean the Text
#     6. Tokenize to get the text max len
#     7. Tokenize to index retrieve vocab length then to sequence then pad it to max length
#     8. Define the model architecture
#     9. Fit on the train data
#     10. Load Pretrained Embedding matrix
#     11. Define model architecture for preloaded embedding matrix
#     12. Fit on training data
#     13. Retrive auc for all the models on test data

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.metrics import roc_auc_score

from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

import re
import string

import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

import warnings
warnings.filterwarnings('ignore')

from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Flatten, GRU, LSTM, Conv1D, MaxPooling1D, Dropout, Activation
from keras.layers.embeddings import Embedding
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91876\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\91876\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91876\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Using TensorFlow backend.

# %%
# READING THE DATA

# %%
quora = pd.read_csv(r"C:\Users\91876\Desktop\Poonam\Python_Project_3\train.csv")

# %%
quora.head()
# Out:
#                     qid                                      question_text  \
# 0  00002165364db923c7e6  How did Quebec nationalists see their province...
# 1  000032939017120e6e44  Do you have an adopted dog, how would you enco...
# 2  0000412ca6e4628ce2cf  Why does velocity affect time? Does velocity a...
# 3  000042bf85aa498cd78e  How did Otto von Guericke used the Magdeburg h...
# 4  0000455dfa3e01eae3af  Can I convert montra helicon D to a mountain b...
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
quora.shape
# Out:
# (1306122, 3)

# %%
quora.target.value_counts(normalize=True)*100  ##IMBALANCED CLASSIFICATION PROBLEM
# Out:
# 0    93.812982
# 1     6.187018
# Name: target, dtype: float64

# %%
#SPLITTING THE DATA SUCH THAT TRAIN AND TEST HAVE SAME TARGET PERCENTAGE

# %%
train,test =train_test_split(quora,test_size=0.25,stratify= quora.target,random_state=123)

# %%
print (train.shape)
print (train.target.value_counts())
test.shape , test.target.value_counts()
# Out:
# (979591, 3)
# 0    918984
# 1     60607
# Name: target, dtype: int64
# ((326531, 3),
#  0    306328
#  1     20203
#  Name: target, dtype: int64)

# %%
x_train= train.question_text
y_train= train.target

x_test=test.question_text
y_test=test.target

# %%
##CREATING FUNCTION FOR CLEANING THE DATA FOR STOP WORDS, TEXT IN BRACKETS , PUNCTUATIONS, WORDS CONTAINING NUMBERS, CORRECTING SHORT FORMS AND LEMMATIZING THE SENETENCE

# %%
def clean_text(text):
    
    text = text.lower().split()
    
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops and len(w) >= 3]
    
    text = " ".join(text)
    
    text = re.sub('\[.*?\]','',text)
    text = re.sub('[%s]' % re.escape(string.punctuation),'',text)
    text = re.sub('\w*\d\w*','',text)
    text = re.sub(r"what’s", "what is ", text)
    text = re.sub(r"\’s", " ", text)
    text = re.sub(r"\’ve", " have ", text)
    text = re.sub(r"n’t", " not ", text)
    text = re.sub(r"i’m", "i am ", text)
    text = re.sub(r"\’re", " are ", text)
    text = re.sub(r"\’d", " would ", text)
    text = re.sub(r"\’ll", " will ", text)
    
    text = text.split()
    
    lemma = WordNetLemmatizer()
    lemma_words = [lemma.lemmatize(word) for word in text]
    
    text = " ".join(lemma_words)
    
    return text

# %%
x_train.describe
# Out:
# <bound method NDFrame.describe of 1026350    How do I select a tyre size and rim size for a...
# 655022     Could Fox buy the rights to Last Man Standing ...
# 526743     James Comey testified the FBI requested access...
# 179882     Why is it that someone, such as Trump for inst...
# 517925     Is there a shortage of trade workers (plumbers...
#                                  ...
# 1294229    How would I make my television show idea a rea...
# 663481     What is the possibility of a having a camera i...
# 273811     Is the discount rate of buying one share of a ...
# 39353      What is the best way to get a personal loan in...
# 104244     Do you think a piloted airplane could fly unde...
# Name: question_text, Length: 979591, dtype: object>

# %%
x_train = x_train.map(lambda x: clean_text(x))

# %%
x_train.head()
# Out:
# 1026350           select tyre size rim size baja atv vehicle
# 655022     could fox buy right last man standing continue...
# 526743     james comey testified fbi requested access hac...
# 179882     someone trump instance whose name people pay m...
# 517925         shortage trade worker plumber carpenter etc u
# Name: question_text, dtype: object

# %%
x_test.head()
# Out:
# 157891            Why can’t I sign up if I’m older than 12?
# 718307         What pictures remind you of something funny?
# 577413    Explain how does a computer help simplying tas...
# 103484            Why doesn't Europe expel all the Muslims?
# 693485    What are the importance of necessity of protec...
# Name: question_text, dtype: object

# %%
x_test = x_test.map(lambda x: clean_text(x))

# %%
x_test.head
# Out:
# <bound method NDFrame.head of 157891                                ca not sign i am older
# 718307                        picture remind something funny
# 577413          explain computer help simplying task example
# 103484                                   europe expel muslim
# 693485     importance necessity protected water supply sy...
#                                  ...
# 197601                                      puzzle pessimism
# 1076955    example successful socialist community commune...
# 349099          judge really woken middle night sign warrant
# 991067                                           earn tinder
# 358803                          beautiful poem english hindi
# Name: question_text, Length: 326531, dtype: object>

# %%
# TOKENIZING TO GET THE LENGTH OF SENETENCE

# %%
question_len=[]

for quest in x_train:
    question_len.append(len(word_tokenize(quest)))

max(question_len)

np.quantile(question_len,0.9999)

question_len1=[]

for quest in x_test:
    question_len1.append(len(word_tokenize(quest)))

# %%
print(max(question_len1))
np.quantile(question_len1,0.9999) ##99.99% OF DATA HAVE LENGTH LESS THAN 29
# Out:
# 34
# 29.0

# %%
max_len=29

# %%
tok = Tokenizer(char_level=False, split=' ') ###INDEXING EVERY WORD OF THE SENETENCE
tok.fit_on_texts(x_train)

tok.index_word
# Out:
# {1: 'get',
#  2: 'best',
#  3: 'would',
#  4: 'people',
#  5: 'like',
#  6: 'good',
#  7: 'one',
#  8: 'make',
#  9: 'india',
#  10: 'year',
#  11: 'way',
#  12: 'time',
#  13: 'think',
#  14: 'many',
#  15: 'life',
#  16: 'much',
#  17: 'someone',
#  18: 'want',
#  19: 'use',
#  20: 'know',
#  21: 'work',
#  22: 'take',
#  23: 'country',
#  24: 'thing',
#  25: 'job',
#  26: 'woman',
#  27: 'ever',
#  28: 'it',
#  29: 'indian',
#  30: 'find',
#  31: 'world',
#  32: 'feel',
#  33: 'become',
#  34: 'person',
#  35: 'without',
#  36: 'book',
#  37: 'could',
#  38: 'student',
#  39: 'better',
#  40: 'quora',
#  41: 'girl',
#  42: 'day',
#  43: 'mean',
#  44: 'company',
#  45: 'difference',
#  46: 'need',
#  47: 'trump',
#  48: 'new',
#  49: 'whats',
#  50: 'possible',
#  51: 'college',
#  52: 'school',
#  53: 'start',
#  54: 'im',
#  55: 'used',
#  56: 'friend',
#  57: 'first',
#  58: 'question',
#  59: 'say',
#  60: 'state',
#  61: 'american',
#  62: 'money',
#  63: 'still',
#  64: 'different',
#  65: 'business',
#  66: 'do',
#  67: 'love',
#  68: 'not',
#  69: 'really',
#  70: 'give',
#  71: 'university',
#  72: 'learn',
#  73: 'long',
#  74: 'old',
#  75: 'change',
#  76: 'even',
#  77: 'help',
#  78: 'study',
#  79: 'right',
#  80: 'engineering',
#  81: 'online',
#  82: 'human',
#  83: 'me',
#  84: 'child',
#  85: 'see',
#  86: 'name',
#  87: 'men',
#  88: 'using',
#  89: 'come',
#  90: 'bad',
#  91: 'stop',
#  92: 'back',
#  93: 'you',
#  94: 'language',
#  95: 'number',
#  96: 'sex',
#  97: 'look',
#  98: 'anyone',
#  99: 'guy',
#  100: 'movie',
#  101: 'system',
#  102: 'muslim',
#  103: 'made',
#  104: 'cause',
#  105: 'place',
#  106: 'getting',
#  107: 'class',
#  108: 'high',
#  109: 'live',
#  110: 'buy',
#  111: 'war',
#  112: 'science',
#  113: 'two',
#  114: 'course',
#  115: 'happen',
#  116: 'exam',
#  117: 'experience',
#  118: 'white',
#  119: 'black',
#  120: 'going',
#  121: 'why',
#  122: 'type',
#  123: 'answer',
#  124: 'cant',
#  125: 'something',
#  126: 'website',
#  127: 'keep',
#  128: 'china',
#  129: 'real',
#  130: 'tell',
#  131: 'government',
#  132: 'computer',
#  133: 'relationship',
#  134: 'month',
#  135: 'free',
#  136: 'them',
#  137: 'example',
#  138: 'water',
#  139: 'english',
#  140: 'problem',
#  141: 'car',
#  142: 'game',
#  143: 'true',
#  144: 'important',
#  145: 'service',
#  146: 'u',
#  147: 'account',
#  148: 'man',
#  149: 'show',
#  150: 'parent',
#  151: 'phone',
#  152: 'career',
#  153: 'food',
#  154: 'every',
#  155: 'always',
#  156: 'never',
#  157: 'word',
#  158: 'home',
#  159: 'reason',
#  160: 'social',
#  161: 'law',
#  162: 'idea',
#  163: 'family',
#  164: 'main',
#  165: 'software',
#  166: 'america',
#  167: 'video',
#  168: 'data',
#  169: 'part',
#  170: 'kind',
#  171: 'future',
#  172: 'chinese',
#  173: 'done',
#  174: 'age',
#  175: 'write',
#  176: 'power',
#  177: 'test',
#  178: 'working',
#  179: 'body',
#  180: 'app',
#  181: 'learning',
#  182: 'another',
#  183: 'mark',
#  184: 'got',
#  185: 'usa',
#  186: 'read',
#  187: 'major',
#  188: 'top',
#  189: 'term',
#  190: 'degree',
#  191: 'cost',
#  192: 'around',
#  193: 'product',
#  194: 'believe',
#  195: 'happens',
#  196: 'medium',
#  197: 'google',
#  198: 'god',
#  199: 'call',
#  200: 'hate',
#  201: 'big',
#  202: 'wrong',
#  203: 'today',
#  204: 'dog',
#  205: 'pay',
#  206: 'president',
#  207: 'able',
#  208: 'for',
#  209: 'point',
#  210: 'effect',
#  211: 'also',
#  212: 'last',
#  213: 'hard',
#  214: 'history',
#  215: 'market',
#  216: 'engineer',
#  217: 'canada',
#  218: 'bank',
#  219: 'process',
#  220: 'city',
#  221: 'play',
#  222: 'ask',
#  223: 'le',
#  224: 'house',
#  225: 'living',
#  226: 'considered',
#  227: 'well',
#  228: 'create',
#  229: 'jee',
#  230: 'end',
#  231: 'normal',
#  232: 'program',
#  233: 'earth',
#  234: 'rank',
#  235: 'score',
#  236: 'card',
#  237: 'site',
#  238: 'instead',
#  239: 'value',
#  240: 'form',
#  241: 'win',
#  242: 'since',
#  243: 'benefit',
#  244: 'prepare',
#  245: 'group',
#  246: 'common',
#  247: 'facebook',
#  248: 'affect',
#  249: 'chance',
#  250: 'great',
#  251: 'order',
#  252: 'technology',
#  253: 'story',
#  254: 'given',
#  255: 'actually',
#  256: 'united',
#  257: 'anything',
#  258: 'now',
#  259: 'writing',
#  260: 'choose',
#  261: 'level',
#  262: 'next',
#  263: 'average',
#  264: 'eat',
#  265: 'medical',
#  266: 'music',
#  267: 'support',
#  268: 'deal',
#  269: 'tip',
#  270: 'making',
#  271: 'option',
#  272: 'current',
#  273: 'song',
#  274: 'view',
#  275: 'lot',
#  276: 'join',
#  277: 'known',
#  278: 'small',
#  279: 'application',
#  280: 'field',
#  281: 'face',
#  282: 'fact',
#  283: 'north',
#  284: 'apply',
#  285: 'kid',
#  286: 'light',
#  287: 'project',
#  288: 'move',
#  289: 'date',
#  290: 'worth',
#  291: 'liberal',
#  292: 'travel',
#  293: 'put',
#  294: 'animal',
#  295: 'design',
#  296: 'force',
#  297: 'talk',
#  298: 'math',
#  299: 'hair',
#  300: 'others',
#  301: 'cat',
#  302: 'area',
#  303: 'south',
#  304: 'control',
#  305: 'is',
#  306: 'this',
#  307: 'open',
#  308: 'tax',
#  309: 'public',
#  310: 'pakistan',
#  311: 'female',
#  312: 'research',
#  313: 'energy',
#  314: 'meaning',
#  315: 'thought',
#  316: 'boy',
#  317: 'care',
#  318: 'increase',
#  319: 'delhi',
#  320: 'called',
#  321: 'character',
#  322: 'management',
#  323: 'religion',
#  324: 'paper',
#  325: 'taking',
#  326: 'marketing',
#  327: 'left',
#  328: 'feeling',
#  329: 'so',
#  330: 'development',
#  331: 'etc',
#  332: 'culture',
#  333: 'improve',
#  334: 'week',
#  335: 'weight',
#  336: 'party',
#  337: 'found',
#  338: 'safe',
#  339: 'male',
#  340: 'space',
#  341: 'away',
#  342: 'post',
#  343: 'education',
#  344: 'skill',
#  345: 'single',
#  346: 'physic',
#  347: 'role',
#  348: 'general',
#  349: 'salary',
#  350: 'side',
#  351: 'international',
#  352: 'rate',
#  353: 'health',
#  354: 'opinion',
#  355: 'stay',
#  356: 'required',
#  357: 'iit',
#  358: 'industry',
#  359: 'function',
#  360: 'christian',
#  361: 'death',
#  362: 'enough',
#  363: 'case',
#  364: 'air',
#  365: 'purpose',
#  366: 'understand',
#  367: 'hour',
#  368: 'mba',
#  369: 'share',
#  370: 'series',
#  371: 'society',
#  372: 'android',
#  373: 'donald',
#  374: 'in',
#  375: 'favorite',
#  376: 'i',
#  377: 'full',
#  378: 'issue',
#  379: 'run',
#  380: 'mind',
#  381: 'have',
#  382: 'political',
#  383: 'based',
#  384: 'programming',
#  385: 'everyone',
#  386: 'the',
#  387: 'build',
#  388: 'master',
#  389: 'stock',
#  390: 'eye',
#  391: 'price',
#  392: 'available',
#  393: 'subject',
#  394: 'gun',
#  395: 'popular',
#  396: 'boyfriend',
#  397: 'behind',
#  398: 'kill',
#  399: 'legal',
#  400: 'wear',
#  401: 'happened',
#  402: 'mobile',
#  403: 'youtube',
#  404: 'military',
#  405: 'admission',
#  406: 'interview',
#  407: 'plan',
#  408: 'try',
#  409: 'often',
#  410: 'girlfriend',
#  411: 'civil',
#  412: 'offer',
#  413: 'watch',
#  414: 'machine',
#  415: 'visa',
#  416: 'second',
#  417: 'said',
#  418: 'dream',
#  419: 'period',
#  420: 'low',
#  421: 'let',
#  422: 'due',
#  423: 'team',
#  424: 'gay',
#  425: 'star',
#  426: 'successful',
#  427: 'russia',
#  428: 'act',
#  429: 'line',
#  430: 'board',
#  431: 'germany',
#  432: 'mass',
#  433: 'theory',
#  434: 'leave',
#  435: 'doctor',
#  436: 'model',
#  437: 'him',
#  438: 'fight',
#  439: 'europe',
#  440: 'there',
#  441: 'topic',
#  442: 'speed',
#  443: 'hindu',
#  444: 'teacher',
#  445: 'institute',
#  446: 'sell',
#  447: 'pain',
#  448: 'per',
#  449: 'quality',
#  450: 'set',
#  451: 'mother',
#  452: 'looking',
#  453: 'advantage',
#  454: 'die',
#  455: 'code',
#  456: 'marriage',
#  457: 'european',
#  458: 'result',
#  459: 'consider',
#  460: 'starting',
#  461: 'similar',
#  462: 'advice',
#  463: 'past',
#  464: 'training',
#  465: 'internet',
#  466: 'information',
#  467: 'everything',
#  468: 'hand',
#  469: 'mechanical',
#  470: 'british',
#  471: 'night',
#  472: 'web',
#  473: 'method',
#  474: 'wife',
#  475: 'amount',
#  476: 'earn',
#  477: 'studying',
#  478: 'turn',
#  479: 'sound',
#  480: 'related',
#  481: 'lose',
#  482: 'korea',
#  483: 'brain',
#  484: 'that',
#  485: 'else',
#  486: 'seen',
#  487: 'effective',
#  488: 'exist',
#  489: 'am',
#  490: 'startup',
#  491: 'modern',
#  492: 'though',
#  493: 'event',
#  494: 'be',
#  495: 'source',
#  496: 'police',
#  497: 'blood',
#  498: 'personal',
#  499: 'australia',
#  500: 'cell',
#  501: 'ive',
#  502: 'rather',
#  503: 'allowed',
#  504: 'treat',
#  505: 'out',
#  506: 'short',
#  507: 'bangalore',
#  508: 'art',
#  509: 'foreign',
#  510: 'universe',
#  511: 'step',
#  512: 'officer',
#  513: 'matter',
#  514: 'already',
#  515: 'famous',
#  516: 'trying',
#  517: 'file',
#  518: 'list',
#  519: 'private',
#  520: 'player',
#  521: 'what',
#  522: 'solution',
#  523: 'difficult',
#  524: 'compared',
#  525: 'mumbai',
#  526: 'developer',
#  527: 'charge',
#  528: 'visit',
#  529: 'worst',
#  530: 'baby',
#  531: 'up',
#  532: 'daily',
#  533: 'professional',
#  534: 'explain',
#  535: 'sign',
#  536: 'easy',
#  537: 'store',
#  538: 'graduate',
#  539: 'member',
#  540: 'married',
#  541: 'sleep',
#  542: 'useful',
#  543: 'biggest',
#  544: 'russian',
#  545: 'skin',
#  546: 'young',
#  547: 'towards',
#  548: 'citizen',
#  549: 'laptop',
#  550: 'rule',
#  551: 'seem',
#  552: 'japanese',
#  553: 'father',
#  554: 'german',
#  555: 'yet',
#  556: 'national',
#  557: 'to',
#  558: 'asked',
#  559: 'knowledge',
#  560: 'chemical',
#  561: 'jew',
#  562: 'follow',
#  563: 'happy',
#  564: 'prevent',
#  565: 'strategy',
#  566: 'news',
#  567: 'coaching',
#  568: 'oil',
#  569: 'nation',
#  570: 'picture',
#  571: 'factor',
#  572: 'iphone',
#  573: 'neet',
#  574: 'film',
#  575: 'correct',
#  576: 'email',
#  577: 'taken',
#  578: 'investment',
#  579: 'material',
#  580: 'contact',
#  581: 'device',
#  582: 'policy',
#  583: 'attack',
#  584: 'rid',
#  585: 'amazon',
#  586: 'middle',
#  587: 'interest',
#  588: 'lost',
#  589: 'started',
#  590: 'cse',
#  591: 'fall',
#  592: 'opportunity',
#  593: 'may',
#  594: 'invest',
#  595: 'user',
#  596: 'islam',
#  597: 'describe',
#  598: 'practice',
#  599: 'size',
#  600: 'download',
#  601: 'basic',
#  602: 'her',
#  603: 'three',
#  604: 'israel',
#  605: 'property',
#  606: 'plant',
#  607: 'branch',
#  608: 'negative',
#  609: 'break',
#  610: 'preparation',
#  611: 'asian',
#  612: 'head',
#  613: 'avoid',
#  614: 'okay',
#  615: 'husband',
#  616: 'thinking',
#  617: 'network',
#  618: 'election',
#  619: 'instagram',
#  620: 'expect',
#  621: 'remove',
#  622: 'cut',
#  623: 'red',
#  624: 'army',
#  625: 'far',
#  626: 'self',
#  627: 'phd',
#  628: 'little',
#  629: 'japan',
#  630: 'security',
#  631: 'employee',
#  632: 'partner',
#  633: 'message',
#  634: 'drive',
#  635: 'provide',
#  636: 'letter',
#  637: 'novel',
#  638: 'natural',
#  639: 'office',
#  640: 'impact',
#  641: 'develop',
#  642: 'likely',
#  643: 'structure',
#  644: 'window',
#  645: 'eating',
#  646: 'present',
#  647: 'grow',
#  648: 'fast',
#  649: 'pro',
#  650: 'gate',
#  651: 'necessary',
#  652: 'speak',
#  653: 'add',
#  654: 'room',
#  655: 'told',
#  656: 'within',
#  657: 'depression',
#  658: 'reading',
#  659: 'modi',
#  660: 'apps',
#  661: 'grade',
#  662: 'on',
#  663: 'drug',
#  664: 'color',
#  665: 'standard',
#  666: 'personality',
#  667: 'large',
#  668: 'situation',
#  669: 'must',
#  670: 'claim',
#  671: 'gain',
#  672: 'treatment',
#  673: 'becoming',
#  674: 'fund',
#  675: 'send',
#  676: 'building',
#  677: 'moving',
#  678: 'go',
#  679: 'accept',
#  680: 'action',
#  681: 'racist',
#  682: 'land',
#  683: 'style',
#  684: 'percentage',
#  685: 'adult',
#  686: 'least',
#  687: 'brand',
#  688: 'illegal',
#  689: 'conservative',
#  690: 'sexual',
#  691: 'digital',
#  692: 'population',
#  693: 'together',
#  694: 'son',
#  695: 'feature',
#  696: 'income',
#  697: 'prefer',
#  698: 'close',
#  699: 'poor',
#  700: 'interested',
#  701: 'fake',
#  702: 'mental',
#  703: 'heart',
#  704: 'check',
#  705: 'credit',
#  706: 'image',
#  707: 'text',
#  708: 'democrat',
#  709: 'crime',
#  710: 'characteristic',
#  711: 'narcissist',
#  712: 'financial',
#  713: 'interesting',
#  714: 'paid',
#  715: 'risk',
#  716: 'nothing',
#  717: 'dating',
#  718: 'western',
#  719: 'photo',
#  720: 'economy',
#  721: 'us',
#  722: 'outside',
#  723: 'race',
#  724: 'non',
#  725: 'scope',
#  726: 'meet',
#  727: 'train',
#  728: 'upsc',
#  729: 'hurt',
#  730: 'page',
#  731: 'placement',
#  732: 'pressure',
#  733: 'allow',
#  734: 'community',
#  735: 'apple',
#  736: 'java',
#  737: 'lead',
#  738: 'special',
#  739: 'higher',
#  740: 'position',
#  741: 'french',
#  742: 'tool',
#  743: 'african',
#  744: 'chemistry',
#  745: 'other',
#  746: 'fat',
#  747: 'nuclear',
#  748: 'gas',
#  749: 'return',
#  750: 'sale',
#  751: 'might',
#  752: 'sport',
#  753: 'mom',
#  754: 'with',
#  755: 'physical',
#  756: 'planet',
#  757: 'fear',
#  758: 'born',
#  759: 'engine',
#  760: 'seat',
#  761: 'pregnant',
#  762: 'changed',
#  763: 'fee',
#  764: 'resource',
#  765: 'drink',
#  766: 'positive',
#  767: 'object',
#  768: 'procedure',
#  769: 'created',
#  770: 'rich',
#  771: 'recommend',
#  772: 'content',
#  773: 'again',
#  774: 'atheist',
#  775: 'marry',
#  776: 'intelligence',
#  777: 'actor',
#  778: 'hotel',
#  779: 'west',
#  780: 'pursue',
#  781: 'talking',
#  782: 'strong',
#  783: 'inside',
#  784: 'crush',
#  785: 'spend',
#  786: 'whole',
#  787: 'link',
#  788: 'solve',
#  789: 'please',
#  790: 'condition',
#  791: 'internship',
#  792: 'uk',
#  793: 'pas',
#  794: 'choice',
#  795: 'about',
#  796: 'hyderabad',
#  797: 'of',
#  798: 'completely',
#  799: 'obama',
#  800: 'currently',
#  801: 'concept',
#  802: 'bring',
#  803: 'bitcoin',
#  804: 'africa',
#  805: 'teach',
#  806: 'smart',
#  807: 'exactly',
#  808: 'early',
#  809: 'are',
#  810: 'dark',
#  811: 'moment',
#  812: 'leader',
#  813: 'channel',
#  814: 'near',
#  815: 'republican',
#  816: 'save',
#  817: 'hindi',
#  818: 'lie',
#  819: 'among',
#  820: 'according',
#  821: 'million',
#  822: 'alone',
#  823: 'certain',
#  824: 'disorder',
#  825: 'activity',
#  826: 'cbse',
#  827: 'technique',
#  828: 'bit',
#  829: 'pune',
#  830: 'yes',
#  831: 'especially',
#  832: 'global',
#  833: 'distance',
#  834: 'reaction',
#  835: 'memory',
#  836: 'korean',
#  837: 'bill',
#  838: 'reduce',
#  839: 'review',
#  840: 'ago',
#  841: 'healthy',
#  842: 'complete',
#  843: 'sister',
#  844: 'needed',
#  845: 'cold',
#  846: 'profile',
#  847: 'minimum',
#  848: 'transfer',
#  849: 'daughter',
#  850: 'manager',
#  851: 'nit',
#  852: 'written',
#  853: 'saying',
#  854: 'blog',
#  855: 'how',
#  856: 'simple',
#  857: 'stupid',
#  858: 'decision',
#  859: 'electrical',
#  860: 'challenge',
#  861: 'court',
#  862: 'fix',
#  863: 'multiple',
#  864: 'dead',
#  865: 'playing',
#  866: 'tamil',
#  867: 'coming',
#  868: 'search',
#  869: 'insurance',
#  870: 'buying',
#  871: 'loan',
#  872: 'giving',
#  873: 'easily',
#  874: 'accomplishment',
#  875: 'advanced',
#  876: 'weapon',
#  877: 'report',
#  878: 'from',
#  879: 'customer',
#  880: 'relation',
#  881: 'note',
#  882: 'summer',
#  883: 'religious',
#  884: 'almost',
#  885: 'individual',
#  886: 'season',
#  887: 'brother',
#  888: 'wish',
#  889: 'east',
#  890: 'mathematics',
#  891: 'importance',
#  892: 'analysis',
#  893: 'clear',
#  894: 'abroad',
#  895: 'tech',
#  896: 'comment',
#  897: 'green',
#  898: 'asking',
#  899: 'platform',
#  900: 'scientist',
#  901: 'football',
#  902: 'prove',
#  903: 'fire',
#  904: 'writer',
#  905: 'lower',
#  906: 'sense',
#  907: 'communication',
#  908: 'blue',
#  909: 'restaurant',
#  910: 'finance',
#  911: 'exercise',
#  912: 'sentence',
#  913: 'temperature',
#  914: 'flight',
#  915: 'he',
#  916: 'survive',
#  917: 'react',
#  918: 'cannot',
#  919: 'immigrant',
#  920: 'running',
#  921: 'sometimes',
#  922: 'later',
#  923: 'manage',
#  924: 'couple',
#  925: 'candidate',
#  926: 'california',
#  927: 'cancer',
#  928: 'stand',
#  929: 'singapore',
#  930: 'fun',
#  931: 'recently',
#  932: 'final',
#  933: 'loss',
#  934: 'ancient',
#  935: 'moon',
#  936: 'economic',
#  937: 'suggest',
#  938: 'all',
#  939: 'developed',
#  940: 'foot',
#  941: 'dollar',
#  942: 'growth',
#  943: 'anxiety',
#  944: 'specific',
#  945: 'front',
#  946: 'economics',
#  947: 'medicine',
#  948: 'clean',
#  949: 'address',
#  950: 'politics',
#  951: 'trading',
#  952: 'killed',
#  953: 'influence',
#  954: 'battery',
#  955: 'center',
#  956: 'certificate',
#  957: 'gender',
#  958: 'detail',
#  959: 'ca',
#  960: 'beautiful',
#  961: 'convert',
#  962: 'hit',
#  963: 'powerful',
#  964: 'enjoy',
#  965: 'heard',
#  966: 'rest',
#  967: 'success',
#  968: 'voice',
#  969: 'acid',
#  970: 'trade',
#  971: 'diet',
#  972: 'secret',
#  973: 'overcome',
#  974: 'longer',
#  975: 'jesus',
#  976: 'perfect',
#  977: 'hold',
#  978: 'key',
#  979: 'seems',
#  980: 'camera',
#  981: 'electric',
#  982: 'despite',
#  983: 'canadian',
#  984: 'continue',
#  985: 'anime',
#  986: 'goal',
#  987: 'ball',
#  988: 'birth',
#  989: 'vote',
#  990: 'compare',
#  991: 'chennai',
#  992: 'recent',
#  993: 'king',
#  994: 'recipe',
#  995: 'soldier',
#  996: 'planning',
#  997: 'hitler',
#  998: 'half',
#  999: 'drop',
#  1000: 'realize',
#  ...}

# %%
vocab_len=len(tok.index_word.keys())
vocab_len
# Out:
# 181603

# %%
seq_train = tok.texts_to_sequences(x_train) ##TRANSFORMING THE SENTENCE TO SEQUENCE OF INDEXED WORDS
seq_train
# Out:
# [[2420, 5194, 599, 8137, 599, 10459, 15910, 1140],
#  [37, 2620, 110, 79, 212, 148, 3015, 984, 370],
#  [1677,
#   6132,
#   43462,
#   2373,
#   6683,
#   1011,
#   3540,
#   7882,
#   1368,
#   4819,
#   1172,
#   68,
#   98,
#   317,
#   5531,
#   182,
#   23,
#   383,
#   1238,
#   336,
#   4095,
#   3302,
#   131,
#   4958,
#   1473],
#  [17,
#   47,
#   3023,
#   1598,
#   86,
#   4,
#   205,
#   62,
#   19,
#   5498,
#   395,
#   2722,
#   22954,
#   7313,
#   10334,
#   673,
#   206,
#   185,
#   2756,
#   24119,
#   2078],
#  [6816, 970, 1566, 11822, 10335, 331, 146],
#  [23, 34, 3, 666],
#  [24, 711, 2139, 35, 160, 344],
#  [6, 1363, 187, 65, 73427],
#  [2, 114, 21978, 2242, 25, 3197, 311],
#  [170, 25, 1222, 167, 25432, 344],
#  [96, 1566, 55, 3810],
#  [1113, 137],
#  [43463, 1653],
#  [511, 53, 351, 2919, 312, 9],
#  [684, 4, 13, 454, 35, 27, 337, 365, 15],
#  [311, 82, 1, 761, 204],
#  [49, 847, 442, 356, 288, 1088, 82, 390, 85],
#  [5030, 3057, 21, 1171, 1365],
#  [122, 169, 12, 25, 106, 62],
#  [21979, 73428, 3387],
#  [14, 576, 147, 381],
#  [884, 33, 803, 3943, 1075, 202],
#  [73,
#   718,
#   1196,
#   5107,
#   443,
#   6432,
#   1715,
#   52791,
#   172,
#   4698,
#   13206,
#   4593,
#   13,
#   23,
#   18,
#   478,
#   2903,
#   14565,
#   22,
#   491,
#   1684,
#   2701],
#  [82, 2461, 562, 1452, 1515, 136],
#  [4718, 1133, 1632, 10, 840, 33, 1654, 76, 6062, 4160, 2494, 66],
#  [104, 703, 20224],
#  [143, 3518, 16, 9611, 3398, 942],
#  [153, 2014, 299, 353],
#  [7994, 4030, 439, 70, 2, 457, 7994, 117],
#  [149,
#   8,
#   8688,
#   7945,
#   2031,
#   1159,
#   886,
#   3448,
#   17,
#   20,
#   7765,
#   227,
#   194,
#   3,
#   2173,
#   250,
#   111],
#  [2670, 32, 8057],
#  [2804, 1399, 293, 3733, 25, 1051, 11650],
#  [73429, 73430, 3811, 2223],
#  [67, 1686, 18, 53, 2394, 587, 731, 1984],
#  [281, 14, 140, 11823, 433, 6, 298, 973, 140, 21050, 433],
#  [1040, 1387, 2968],
#  [30, 6, 632, 53, 65],
#  [21, 73431, 2044],
#  [5, 109, 2702, 2513],
#  [52792,
#   73432,
#   311,
#   4238,
#   339,
#   146,
#   211,
#   1876,
#   339,
#   209,
#   24,
#   311,
#   87,
#   30,
#   52793],
#  [964, 1217, 139, 482],
#  [5249, 43464, 72, 94],
#  [2359, 2236, 46, 415, 292, 64, 23, 11651, 35, 415, 356],
#  [1812, 890, 16731],
#  [2207, 264, 301],
#  [2536, 344, 1187, 113, 802, 25, 49, 137, 1540, 714, 1325],
#  [399, 10592, 810, 472, 1660],
#  [110, 52794, 1422, 5561, 319],
#  [172, 25433, 1442, 4, 31],
#  [1143, 2568, 2180],
#  [143, 11333, 395, 9, 7314, 7314, 5562, 443, 3827, 11333, 5562, 102, 443],
#  [14891, 63, 1477],
#  [29, 1115, 413, 1026],
#  [41, 761, 2395, 2079],
#  [8845, 2876, 845, 7490],
#  [401, 207, 893, 65, 907, 4699, 21980, 895, 5969, 464],
#  [806, 3895, 37812, 25, 71, 97, 178, 148],
#  [551, 64, 372, 151, 64],
#  [297, 192, 4, 42, 42, 1241, 2208, 32, 5, 376, 489, 120, 3880, 66],
#  [36, 2, 1097, 559, 132, 112, 731, 383, 7491, 1593],
#  [2495, 2448, 4406],
#  [115, 5855, 2555, 20225, 1879, 188, 676],
#  [578, 39, 9507, 3607, 3881],
#  [16, 1503, 82, 369, 11186],
#  [1718, 465, 7995, 2722, 9844],
#  [771, 181, 7, 94, 12],
#  [1684, 2306],
#  [408, 262, 10593, 3068],
#  [5, 28844, 3507, 39],
#  [25434, 2996, 1567, 1120, 500, 104],
#  [202, 525, 29],
#  [827, 52795, 19, 10336, 2936, 192, 3378, 8325, 168, 449, 88, 168, 73433],
#  [585, 3484, 43465],
#  [2, 449, 3971, 158, 270, 1, 39, 391, 531, 889],
#  [7552, 13207, 39, 469, 828, 2449],
#  [2085, 298, 728, 2068, 298, 2194, 393],
#  [14, 569, 865, 8058, 3198, 31, 1499],
#  [376, 4518, 2980],
#  [543, 140, 58, 3435, 89, 1221, 516, 260, 2086, 664, 654],
#  [7826, 26, 6586, 7216, 1422, 1553, 6848, 303, 1352, 57, 452, 934, 6099],
#  [213, 73434, 99, 1, 43466, 41],
#  [2390, 12994, 10460, 146, 363],
#  [107, 52, 78, 374],
#  [530, 454, 10461],
#  [542,
#   680,
#   18229,
#   2768,
#   16311,
#   539,
#   457,
#   4500,
#   4371,
#   4500,
#   13208,
#   6939,
#   1249,
#   1196,
#   3598],
#  [827, 8689, 171],
#  [7946, 13962, 1225, 782, 3558, 8262, 1529],
#  [104, 6684, 4481, 2748],
#  [504, 163, 39, 73435, 4218, 457, 37813, 5052],
#  [245, 39, 9733, 176, 855, 671, 17179, 28, 291, 689],
#  [165,
#   945,
#   230,
#   92,
#   230,
#   5407,
#   533,
#   669,
#   388,
#   7,
#   72,
#   35,
#   120,
#   445,
#   2530,
#   52796,
#   36,
#   86,
#   1665,
#   5532],
#  [401, 2947, 500, 312, 4838],
#  [13,
#   40,
#   4736,
#   7883,
#   2140,
#   3734,
#   5230,
#   787,
#   22,
#   595,
#   126,
#   169,
#   16312,
#   2102,
#   383,
#   2237,
#   1150,
#   565],
#  [686, 2321, 441, 40],
#  [5533, 2124, 227, 4655],
#  [1573,
#   681,
#   906,
#   2974,
#   17,
#   2209,
#   2450,
#   13209,
#   2450,
#   11493,
#   1498,
#   31022,
#   1961,
#   809,
#   2789],
#  [1678, 94, 3024, 1735, 457, 23],
#  [659,
#   4780,
#   123,
#   40,
#   5,
#   915,
#   4780,
#   196,
#   224,
#   42,
#   43,
#   5322,
#   714,
#   1271,
#   178,
#   42,
#   471,
#   40,
#   127,
#   5322,
#   706,
#   9845],
#  [2385, 8690, 127, 2898, 58],
#  [2, 5669, 2141],
#  [1414,
#   734,
#   51,
#   38,
#   848,
#   1261,
#   10,
#   51,
#   38,
#   10,
#   181,
#   63,
#   46,
#   4903,
#   1541,
#   4104,
#   848,
#   71,
#   5,
#   6505,
#   7666],
#  [33956, 52797, 267, 120, 741, 2537, 618],
#  [4, 109, 15],
#  [143, 975, 156, 3252, 694, 198, 201, 7996],
#  [4254, 2701, 12566],
#  [3388, 446, 821, 290, 3103],
#  [1, 5172, 17, 52, 21051, 153],
#  [7, 56, 655, 1580, 118, 4, 488, 902, 202],
#  [168, 955, 288, 1407, 12, 305, 3269, 3476, 168, 955, 33, 24, 463],
#  [14, 2056, 1313, 381],
#  [956, 724, 825, 284, 73436, 18, 1153, 3726, 383, 146],
#  [2588, 1424, 1280, 171, 6433, 35, 5323, 169, 1293, 88, 8539, 296],
#  [926, 598, 4255],
#  [44, 7553, 248],
#  [205, 241, 142, 5, 142, 111, 63, 8462, 76, 492, 14, 90, 839, 15552, 879],
#  [133, 52798, 73437, 73438, 5, 2195],
#  [3204, 151, 1, 1016],
#  [116, 5, 4519, 301, 318, 2322],
#  [160, 936, 1507, 3, 6848, 143, 73439, 1424, 776, 145, 2824, 1228, 392, 98],
#  [1533, 2148, 2589, 179, 756, 935, 33, 976, 3583],
#  [30, 3199, 273, 73440, 28845, 73441],
#  [1, 86, 165, 232, 4800],
#  [365, 624, 18825, 1032, 169, 281],
#  [17, 33, 9394],
#  [5805,
#   7884,
#   221,
#   236,
#   1,
#   1320,
#   431,
#   2016,
#   1267,
#   1527,
#   745,
#   37,
#   5774,
#   845,
#   111,
#   1599,
#   236,
#   39],
#  [5130, 5088, 2825, 359],
#  [4, 106, 7603, 249, 1358, 15, 12],
#  [45, 73442, 43467, 43467],
#  [1390, 288, 12375],
#  [2595, 11014, 10872],
#  [43468, 148],
#  [1690, 11652, 516, 125, 124, 66],
#  [1160, 293, 230, 2472, 3477, 1779, 41, 10, 3, 85, 54],
#  [546, 38, 128, 1727, 1561, 1697],
#  [8611, 13686, 10, 174],
#  [12794, 21052, 261, 108, 3629, 1921, 648],
#  [1, 118, 148, 456],
#  [604, 2617, 112, 252, 982, 282, 1533, 86, 323],
#  [195, 2511, 37814, 3016, 21981, 12, 1478, 1051],
#  [527, 2569, 17, 88, 4372, 2057, 2608, 547, 93, 1631],
#  [140, 1223, 301, 25, 10],
#  [893, 1837, 4594],
#  [2, 52, 3944, 80],
#  [1368, 2571],
#  [73443, 1332, 10337, 171, 3312, 1528],
#  [446, 141, 54, 63, 1242, 28, 848, 141, 446, 28, 970, 374],
#  [852, 123, 377, 912, 2196, 2749, 52799, 183, 7169],
#  [50, 186, 633, 35, 7032, 1087],
#  [4839, 15553, 286, 1868, 1085, 4391, 1135, 1325],
#  [929, 4634, 26957, 5089, 5806, 203, 13, 3120, 262, 206, 929, 121],
#  [2514, 24, 3769, 73444, 24, 1430],
#  [5378, 4700, 1272, 2589, 5378, 1154, 933, 676],
#  [333, 554, 94, 2217],
#  [251, 307, 909, 217, 46, 956],
#  [128,
#   900,
#   8,
#   1043,
#   4256,
#   203,
#   4256,
#   852,
#   172,
#   139,
#   651,
#   509,
#   900,
#   72,
#   172,
#   186,
#   1043,
#   4256,
#   10084,
#   128,
#   900],
#  [515, 3176, 796],
#  [1703, 39, 34, 4049],
#  [175, 1612, 1612, 465, 126],
#  [1301, 770],
#  [13433, 198, 1915, 82],
#  [3, 56, 2045, 270, 930, 843, 702, 353, 378, 76, 492, 655, 14, 12, 91, 28],
#  [1862, 33957, 1269, 6434],
#  [6, 90, 1849, 52800, 431],
#  [78, 3351, 416, 94, 2575, 4781, 345, 36, 555],
#  [4121, 320, 903, 2630],
#  [4199, 2621, 17, 1581, 194, 143],
#  [14251, 52801, 18826, 28846, 31],
#  [333, 2414, 578, 858, 4373, 892],
#  [550, 2850, 4656, 8059, 3038, 6726],
#  [413, 836, 2870, 4407],
#  [2531, 3002, 19, 37815, 12192, 12],
#  [1876, 85, 73445, 1671, 106, 13963, 10085],
#  [1498, 5775, 9019, 586, 889],
#  [14566, 17180, 2871],
#  [137, 33958, 3150],
#  [2774, 160, 630, 73, 916, 37, 1592, 261, 185, 43, 1201, 33, 5, 7604, 941],
#  [73446, 1196, 240, 131, 1327],
#  [3389, 67, 6506, 39, 739, 4520, 93],
#  [143, 10594, 589, 3028, 96, 872, 3798, 25, 3959],
#  [75, 553, 86, 1313],
#  [599, 172, 390, 1557, 836],
#  [658, 5563, 1672, 12],
#  [304, 5379, 76, 492, 169, 217],
#  [209, 1843, 36, 770, 1264, 699, 1264, 2025, 21982],
#  [56, 775, 148, 1824, 853, 2061, 558, 77, 85, 896, 66],
#  [49, 2, 11, 19, 4840, 21, 1216],
#  [303, 743, 200, 3709],
#  [1156, 4673, 146],
#  [103, 997],
#  [1226, 946],
#  [7, 105, 156, 12193, 474],
#  [118, 141, 146, 260, 246, 664],
#  [2462, 295, 1668, 24120, 2735, 37816, 1668, 3029],
#  [1180, 6587, 683, 2496, 21983, 37817, 1483, 36, 2708, 1483],
#  [7, 32, 2110],
#  [8463, 73447, 73448],
#  [470, 139, 762, 212, 113, 1144],
#  [37, 2780, 1595, 816, 163, 6316, 6685, 65, 1147, 320, 73449],
#  [323, 52802, 17651, 8060, 9612, 21053, 13210, 25435, 360],
#  [819, 1103, 144, 2218, 8138, 26958, 3150],
#  [191, 226, 6, 268, 749, 3029, 525, 1489, 26959],
#  [377, 86, 820, 5131, 1409],
#  [1877, 313, 101, 8386, 7605, 2062, 534, 137],
#  [18230, 18230, 2425],
#  [14, 857, 4, 40, 653, 239, 58],
#  [2, 12, 1369, 6686, 1424, 16732],
#  [17, 228, 65, 2396, 1198, 3368],
#  [3086, 52803, 73450, 74],
#  [2, 174, 244, 1090],
#  [3836, 15196, 365],
#  [713, 73451, 2872, 24, 6241],
#  [1856, 947, 343, 25, 1191, 11187, 10338, 9],
#  [29, 225, 894, 1679, 9],
#  [620, 37818, 4841, 183, 573, 60, 1789, 6003, 1002],
#  [893, 1033, 670, 103, 2002, 102, 534, 3945, 634, 14, 3972, 102, 4185],
#  [1292, 11, 674, 490],
#  [54, 10, 74, 225, 158, 56, 409, 32, 2826, 8, 56],
#  [11015, 962, 52804, 4292],
#  [1391, 177, 338, 11, 130, 1284, 6, 68],
#  [436, 9613, 3180, 4959, 3389, 754, 990],
#  [1371, 45, 3508, 3508, 1833],
#  [11995, 39, 809, 11],
#  [859, 3863, 718, 439, 64, 256, 60],
#  [486, 31, 936, 5631, 6894, 3151, 262, 7, 50, 104],
#  [1469, 1140, 52805, 262, 10, 9959, 832, 946, 950, 1021],
#  [3525, 2736, 6646],
#  [511, 22, 175, 1618, 839],
#  [26, 1397, 99, 32, 3165, 1285, 699, 83, 15, 4134],
#  [1711, 581, 16313, 15911],
#  [4002, 8935, 7267, 6, 90, 321, 25436, 90, 321],
#  [3, 337, 694, 270, 99],
#  [3058, 472, 1392, 53, 19490, 65],
#  [284, 25, 48, 2032, 1600, 1098, 1314, 190, 146],
#  [290, 276, 103, 536, 177, 370, 17181],
#  [3686, 865, 7885],
#  [137, 19491, 2391],
#  [373, 47, 544, 1271, 5408, 1816],
#  [902, 26960, 2245, 1197],
#  [1414,
#   1042,
#   608,
#   502,
#   766,
#   608,
#   315,
#   19,
#   2383,
#   1420,
#   766,
#   315,
#   1222,
#   307,
#   380,
#   893,
#   7427,
#   3657,
#   2307,
#   73452],
#  [137, 2168, 21054, 1049],
#  [303, 482, 131, 4719, 172, 5053, 3157, 228, 5302, 128],
#  [1808, 77, 419, 4635],
#  [1736, 4148, 4, 20226, 1467],
#  [847, 2021, 844, 349, 45, 60, 9],
#  [2476, 17182, 3030, 1, 1028],
#  [51, 6, 52806, 3411, 35, 298, 1340],
#  [13964, 285, 5173, 2133, 358],
#  [3, 31, 559, 135, 11016, 17652],
#  [1, 100, 2120, 100, 253],
#  [10873, 155, 516, 1, 663, 83],
#  [20,
#   30,
#   389,
#   719,
#   129,
#   26,
#   240,
#   1554,
#   599,
#   1259,
#   1169,
#   14892,
#   664,
#   24,
#   15,
#   752,
#   2832,
#   3882,
#   2781,
#   21,
#   16733,
#   331],
#  [26961, 3104, 11188],
#  [665, 36, 469, 393, 73453],
#  [3023, 1773, 24, 321, 7715, 7428, 19492],
#  [1865, 11, 1205, 1201],
#  [50, 142, 1392, 1510, 16, 349, 3, 1],
#  [2571, 2249, 2062, 73454, 1073, 2249, 85, 958, 4595, 892],
#  [106, 9508, 1308, 9846, 956, 10086, 9, 509, 38, 405, 651, 1, 28],
#  [297,
#   155,
#   2515,
#   4456,
#   225,
#   163,
#   1924,
#   288,
#   505,
#   18,
#   297,
#   17,
#   54,
#   1854,
#   30,
#   505],
#  [1826, 264, 8464],
#  [30, 10339, 17183, 3703, 250, 461, 2854, 695],
#  [872, 6200, 636, 784, 156, 4149, 8387, 577, 6, 162],
#  [4, 260, 818, 76, 1806, 1100, 3864, 68, 104, 1981],
#  [50, 228, 8846, 295, 4200, 455, 180, 88, 1269, 295],
#  [20227, 103, 797],
#  [640, 509, 1250, 322, 428],
#  [110,
#   26,
#   1215,
#   1830,
#   2882,
#   1760,
#   110,
#   3497,
#   1215,
#   5303,
#   1215,
#   19493,
#   5303,
#   110,
#   1215],
#  [18827, 6063],
#  [2, 105, 109, 73455],
#  [4, 13965, 156, 965, 975, 1574],
#  [106, 366, 5564, 1371, 745, 964, 133],
#  [47,
#   962,
#   708,
#   14,
#   815,
#   8388,
#   163,
#   16734,
#   163,
#   4219,
#   3681,
#   60,
#   28847,
#   26,
#   775,
#   2242,
#   87,
#   5776,
#   1613,
#   712,
#   2012],
#  [18, 1707, 41, 59, 52807, 34, 7492, 143, 8, 1707],
#  [124, 131, 149, 5132, 3399, 240, 4105, 242, 3336, 16, 18231, 1516, 523, 413],
#  [73456, 39, 6400],
#  [16, 2547, 9196],
#  [321, 43469, 43470, 10340, 28848, 2133, 370, 425, 3639, 262, 1150],
#  [1476,
#   84,
#   58,
#   4220,
#   198,
#   1187,
#   2984,
#   86,
#   697,
#   323,
#   11,
#   3253,
#   33959,
#   35,
#   12795,
#   1038,
#   883,
#   78,
#   7268,
#   1043,
#   1641,
#   5231],
#  [608, 239, 73457, 3909, 43],
#  [2054, 11, 130, 90, 566],
#  [1797, 73458, 43471, 785, 886, 538, 1633, 71, 13687],
#  [642, 285, 194, 239, 2805, 2761, 4737, 150],
#  [36, 46, 562, 728, 116, 60, 1815, 5273, 393],
#  [16, 3, 191, 110, 7886, 9],
#  [5, 17, 1766, 2723, 700, 93, 63, 130, 328, 4701, 13211, 922],
#  [96, 3910],
#  [59, 5632, 1692, 1, 65, 39, 268, 465, 968],
#  [106, 37819, 319, 2226, 9299],
#  [1439, 9509, 7827, 103],
#  [1, 158, 871, 35, 1242, 22955],
#  [43, 842, 1817, 359],
#  [49, 455, 4636, 8326, 1761],
#  [2, 269, 948, 12376],
#  [73459, 2141, 6991],
#  [15912, 73460, 5, 123, 58],
#  [164, 3038, 433, 694, 2231],
#  [5907, 63, 46, 3425],
#  [7, 713, 34, 3449, 277],
#  [453, 345, 336, 101],
#  [13, 992, 4838, 1017, 10202, 168, 8847, 4536],
#  [7, 39, 780, 190, 6542, 8389],
#  [1338, 539, 1070, 1474, 273, 855],
#  [845, 814, 784],
#  [3640, 28849, 64, 500],
#  [1, 4257, 595, 109, 1707, 742, 363, 4563, 46, 28, 787, 742, 73461],
#  [9847, 1272, 993],
#  [218, 2, 1762, 490],
#  [73, 4186, 355, 7033, 101],
#  [770, 20228, 13, 9960],
#  [1229],
#  [16, 7, 636, 5908, 2323, 191],
#  [159, 7429, 300, 4],
#  [31023, 6435, 606],
#  [4457, 12377, 302, 414, 181, 480, 414, 181],
#  [1152, 2368, 125, 420, 6849, 130, 1046],
#  [7217, 572, 3763],
#  [893, 229, 164, 52808],
#  [1456, 1596, 1893, 12, 104, 483, 1310],
#  [1678, 1, 9848, 157, 4, 59],
#  [837, 1253, 1, 793, 291, 770, 118, 963, 339, 1498, 459, 377, 6278, 4392],
#  [37,
#   4,
#   679,
#   3400,
#   4782,
#   4701,
#   82,
#   79,
#   124,
#   85,
#   3,
#   3205,
#   262,
#   1150,
#   124,
#   13,
#   3337,
#   779,
#   155,
#   4302,
#   18828,
#   4],
#  [24, 222, 1153, 1329, 3094, 145],
#  [1050, 4, 149, 6507, 866, 15913, 3338, 15197, 328],
#  [49, 2189, 294, 719, 486],
#  [8196, 104, 8263, 121],
#  [4316, 605, 20229],
#  [78, 14567, 114, 804],
#  [1153, 141, 10203, 52809],
#  [263,
#   61,
#   1517,
#   1665,
#   1136,
#   4960,
#   559,
#   14,
#   280,
#   532,
#   15,
#   24121,
#   7315,
#   72,
#   1435,
#   1585,
#   524,
#   966,
#   57,
#   31,
#   23,
#   343,
#   101],
#  [774, 63, 2761, 198, 76, 361, 1234, 212, 367],
#  [141, 2121, 164, 159, 104, 4, 783, 141, 454],
#  [278, 2333, 6133, 1493],
#  [37, 104, 1160, 2516, 1317],
#  [6100, 60, 16735, 2833],
#  [353, 1036, 1827, 2125, 28850, 9106],
#  [550, 2987, 31024, 10204, 14, 3584, 356, 1395],
#  [1, 1844, 632],
#  [85, 1276, 286, 2350, 390, 390, 2409],
#  [8848, 1322, 13966, 4408, 11189],
#  [648, 153, 25, 90, 4, 59],
#  [15, 1018, 82, 692, 814, 31, 2877, 1858, 585, 1858, 5],
#  [16, 191, 53, 11017, 672, 9, 8061, 7034, 672, 53],
#  [5777, 706, 18829, 706, 73462],
#  [1036, 8, 18232, 2003],
#  [798, 91, 645, 54, 90, 3571],
#  [32, 33960, 749, 865, 901, 2904],
#  [2351, 904, 1916, 10595],
#  [1106, 9, 14893, 84],
#  [2, 30, 27, 21055],
#  [171, 391, 4209],
#  [394, 161, 2168],
#  [27, 1619, 11996, 150, 830, 121],
#  [1756, 858, 1042, 229, 1869, 2477],
#  [243, 1231, 15554],
#  [2841, 3270, 699, 1504, 23, 305],
#  [453, 1027, 13967],
#  [399, 110, 2359, 2236, 48, 13968, 1343],
#  [21984, 4333, 9020],
#  [2054, 19, 189, 509, 2126, 459, 5007, 4984, 26962, 8197, 832, 2961],
#  [209, 40, 1012, 3181, 14, 7766, 4239],
#  [6201, 26963, 454],
#  [29, 218, 70, 871, 5778, 2051, 12995, 65, 35, 3641, 205, 475, 134],
#  [6, 362, 22, 405, 1383, 5633, 607, 4150, 171, 287],
#  [73463, 73464, 48, 14894, 1215, 14895, 248, 8264, 358],
#  [6777, 3131, 3131, 1860],
#  [132, 112, 538, 873, 1032, 225, 2296, 1894, 388, 190, 894, 3547, 431],
#  [4820, 1126, 810, 2463, 119],
#  [20, 14, 157, 8, 912, 257, 3, 77, 1, 28],
#  [860, 2551, 11824, 3443],
#  [45, 33961, 11018, 450, 433],
#  [246, 172, 148, 775, 552, 311, 33962, 121],
#  [54, 2981, 272, 3764, 107, 3, 5, 805, 73465, 3, 771, 329],
#  [1007, 4334, 686, 764, 1687, 379, 372, 1989, 28],
#  [30, 75, 5881, 1042, 5909, 1698],
#  [9961, 2344, 4882],
#  [1237, 661, 646, 31, 1865],
#  [39, 560, 828, 2449, 411, 828, 796],
#  [18233, 14252, 257, 7667, 1235, 1183, 223, 52810, 37820, 1909, 140],
#  [849, 13434, 6727, 7363, 71, 652, 98, 2671, 107, 90],
#  [98, 13, 3, 89, 1895, 217, 493, 111, 10596, 47, 2443, 2444, 25437],
#  [18830, 18831, 10087, 312],
#  [98, 486, 424, 924, 9],
#  [2703, 299, 299, 21056],
#  [23, 3, 199, 2464, 7218],
#  [16, 12, 356, 78, 147, 712, 15555, 959],
#  [6134, 539, 52811, 12567],
#  [31025, 66],
#  [2782, 1698],
#  [792,
#   813,
#   1093,
#   149,
#   10874,
#   8849,
#   11653,
#   73466,
#   3883,
#   3787,
#   14253,
#   2656,
#   18832,
#   43472,
#   2608,
#   8848,
#   732,
#   1774,
#   9614,
#   1868,
#   371],
#  [7035, 94, 4842, 50, 11, 72, 7035, 158],
#  [600, 177, 218, 5473, 15198, 1976, 73467],
#  [1056, 239],
#  [927, 43473, 243, 4596],
#  [6401, 3694, 12796, 843, 6895, 887, 161],
#  [536, 893, 6064, 1104, 116],
#  [305, 68, 224, 903, 21053, 1247, 1732, 273],
#  [11825, 190, 11654, 298],
#  [26, 13, 452, 90, 452, 99],
#  [3, 28851, 337, 99, 337, 1101, 2631, 93],
#  [704, 41, 173, 96, 4221],
#  [128, 92, 2243, 283, 482, 9395, 146, 583, 33963],
#  [725, 309, 1673],
#  [625, 4925, 31026, 292, 4015, 649, 4925, 142],
#  [841, 1880, 162, 113, 4, 3, 127, 4374, 837],
#  [338, 73468],
#  [268, 1666, 2576, 378, 663, 1268, 693, 408, 77, 155, 379, 341],
#  [2920, 11494, 14568, 4122],
#  [3, 398, 1773],
#  [2, 858, 103, 40],
#  [94, 144, 65, 172, 544],
#  [3, 3369, 718, 9197, 1578],
#  [3076, 143, 666],
#  [278, 1338, 2139, 30, 15914, 342, 58, 772],
#  [122, 971, 5670, 481, 335],
#  [56, 703, 1555, 3788, 139],
#  [78, 242, 1018, 1804, 71, 292, 1404],
#  [1050, 1367, 223, 2406, 29],
#  [191, 7, 1698, 126, 9],
#  [87, 6, 4926, 410, 474],
#  [1151, 206, 194, 3291, 1207],
#  [10,
#   922,
#   501,
#   2156,
#   3200,
#   8,
#   5250,
#   808,
#   1208,
#   379,
#   2547,
#   192,
#   4106,
#   355,
#   11334,
#   1855,
#   1006,
#   367],
#  [376,
#   381,
#   3181,
#   48,
#   2435,
#   28852,
#   3642,
#   884,
#   154,
#   345,
#   42,
#   480,
#   25,
#   592,
#   156,
#   1476,
#   66,
#   68,
#   85,
#   209,
#   376,
#   489,
#   700,
#   120,
#   729,
#   73,
#   379],
#  [124, 2209, 4, 619],
#  [1336, 63, 1991, 986],
#  [131, 1108, 146],
#  [399, 128],
#  [73469, 34, 1911, 12797, 2022, 1601, 362, 362],
#  [72, 5563, 73470],
#  [19, 1987, 2354],
#  [2, 52812, 820, 93],
#  [820, 11655, 2704, 24, 6, 2219],
#  [37821, 21057, 15556, 5441],
#  [37822, 12],
#  [614, 194, 1552, 75, 24122, 267, 1223, 564, 10205, 210],
#  [14, 14569, 43474, 266, 1338],
#  [40, 322, 7828, 377, 304, 6687],
#  [2497, 311, 1479, 1678, 32, 223, 5409, 1188, 1102, 118, 339, 2210, 1022],
#  [641, 658, 1208, 1, 2981, 4424],
#  [20, 490, 4031],
#  [1018, 6508, 55, 5442, 2457],
#  [1857, 651, 219, 181],
#  [517, 696, 308, 749, 240, 800, 55, 4944, 749],
#  [250, 29, 666, 1122, 347, 436, 207, 243, 15, 2402],
#  [395, 9107, 185],
#  [2650, 589, 11826],
#  [187, 493, 48, 1137, 220, 256, 60, 5067, 646],
#  [109, 154, 42, 5, 212, 2796, 5251, 264, 5, 765, 18, 5, 66, 98, 485, 306],
#  [1790, 51, 4063, 2548, 162],
#  [761, 9108, 8327],
#  [9962, 770, 2899, 2956],
#  [22, 48, 7269],
#  [1603, 4016, 2905, 2064, 37, 1065, 18, 70, 773, 6, 858],
#  [1140, 95, 2055],
#  [6469, 1566, 1741],
#  [2288, 5499, 81, 116],
#  [11495, 1284, 55, 299],
#  [164, 1322, 370, 603, 1979],
#  [375, 73471, 3176, 121],
#  [52, 11019, 52, 2796, 3789, 422, 1120, 3559],
#  [3, 2, 384, 94, 287],
#  [13, 47, 408, 19494, 15915, 1277, 2804, 1741],
#  [13969, 564, 8265, 2350, 13688, 5380],
#  [6135, 852, 820, 2002],
#  [548, 23, 226, 1113, 176, 699, 2789, 16, 712, 1592],
#  [228, 402, 279, 88, 2276, 455],
#  [63, 67, 4335, 12],
#  [72, 57, 660, 330, 472, 330, 2583, 736, 49, 19, 1103],
#  [22, 1090, 567],
#  [7997, 2340, 142, 27, 143, 2340, 4, 221, 28],
#  [574, 3682, 1672, 62, 1219, 5830, 105, 1516, 9198],
#  [18, 41, 56, 22, 4702, 1155, 70, 340],
#  [43475, 3973, 19, 37823, 73472, 7],
#  [1050, 574, 358, 8, 111, 100, 5970, 932, 2390, 100],
#  [131, 1199, 348, 2678, 38, 1090, 567],
#  [3003, 996, 73473, 3883, 939],
#  [201, 2957, 12, 105, 767, 510],
#  [4336, 5031, 291],
#  [173, 3450, 1075, 12194, 202],
#  [6, 2538, 1612, 36, 181, 15199, 24123, 10875],
#  [2769, 1809, 941, 17, 4425, 16],
#  [3390, 376, 489, 1326, 13, 4409, 12, 75, 315, 3206, 1216, 121],
#  [3, 63, 78, 1684, 80, 37, 92, 51],
#  [2, 62, 2469, 126, 35, 578, 169, 12, 1566],
#  [12568, 73474, 277, 208],
#  [1321, 535, 1546, 3687],
#  [14, 393, 260, 10],
#  [7, 56, 4597, 7316, 17, 248, 56, 1568, 152, 25, 1646, 1059, 3189],
#  [3, 292, 935, 37, 3, 109, 440, 68],
#  [19, 11335, 23, 3526, 62, 3780, 23],
#  [378, 11656, 7668],
#  [18833, 455, 15200, 455],
#  [40, 14570, 7317, 5457],
#  [8, 150, 1586, 33964, 1806, 116, 90, 502, 1388, 458, 70, 5409],
#  [11336, 112, 2278, 1100, 2437, 1100],
#  [651, 17, 17, 1537, 957],
#  [12569, 27, 12996, 6063, 2087, 2268, 858],
#  [104, 3339, 17184],
#  [37, 17, 591, 7, 8390, 67, 10, 1738, 41],
#  [49, 2149],
#  [8, 4064, 1875, 64, 86, 242, 5500, 365, 1395, 43476, 86],
#  [832, 247, 43477, 7124, 165, 330, 490, 37, 4003, 145],
#  [1369, 15557, 3541, 8391],
#  [763, 958, 842, 2678, 661],
#  [4985, 1374, 245, 87, 26, 14, 11, 173, 8328, 4985, 669, 148],
#  [1130, 1588, 36, 186, 57, 12, 685, 333, 2379, 658, 344, 658, 9109, 344],
#  [3498, 52813],
#  [12570, 3451, 37824, 16314],
#  [1264, 174, 3087, 275, 1044, 54, 915, 5, 258, 285, 452, 33965, 223, 1965],
#  [37, 50, 159, 577, 73, 1273, 150, 1435, 2057, 547, 1281, 15, 3548],
#  [640, 612, 35, 6317, 677, 104, 9615, 329, 855, 254, 483, 3, 640, 6317],
#  [601, 140, 1878, 2164, 2651, 1448, 132],
#  [199, 2556, 176],
#  [384, 94, 7318, 673, 5611, 455, 63, 13970, 362, 359, 14, 2246, 258],
#  [172, 548, 11496, 503, 276, 624, 387, 2308],
#  [2, 567, 445, 368, 525],
#  [354, 14571, 14252],
#  [64, 52814, 526, 476, 3131, 2209, 1931],
#  [18234, 20, 582, 838, 449, 15, 856, 5718, 85, 2197, 1629, 756],
#  [3182, 7036, 2165],
#  [28853, 52815, 73475, 3608],
#  [8, 1278, 273],
#  [3, 597, 272, 25, 347, 6728],
#  [3, 2804, 248, 29, 38, 18, 78, 792],
#  [14, 8464, 2503, 2914, 3114],
#  [15558, 8264, 2309, 1198, 667, 765, 391, 3919, 739, 196, 765],
#  [2360, 2525, 3088, 69, 338, 1812],
#  [1480, 327, 79, 2026, 82, 179],
#  [49, 164, 140, 1917, 1170],
#  [2289, 344, 5565, 13212, 3688, 4440, 178, 133, 2189, 907, 344],
#  [209, 259, 7493, 5669],
#  [13, 9300, 1613, 378, 166, 800, 2551],
#  [806, 579, 75, 7767],
#  [603, 31027, 240, 16315, 2103],
#  [390, 551, 11497, 207, 212, 1281, 15],
#  [1280, 10735, 425, 2584, 510],
#  [61, 61, 382, 812, 1474, 11020, 382, 176, 4107, 1321, 11, 91, 4107],
#  [1116, 9],
#  [5381, 139, 298, 2196, 107, 1716, 5670, 36],
#  [277, 291, 508, 343],
#  [8, 148],
#  [580, 97, 631, 243, 271],
#  [7, 4986, 1059, 1739, 113, 35, 21, 2855, 301, 2224, 6, 2577, 3242, 6, 51],
#  [2017, 1225, 1686, 286, 637],
#  [3, 241, 438, 16736, 1786],
#  [247, 27, 1312, 633, 1794, 350, 1095, 1312, 147],
#  [25438, 5458, 2092],
#  [622, 291, 16737, 7768],
#  [10597, 2071, 14572, 3401],
#  [315, 43478, 5354, 3182, 963, 3121, 20230, 759],
#  [847, 234, 106, 1013, 760],
#  [106, 3485, 865, 26964, 1490, 289],
#  [133, 5807, 82, 6543],
#  [2609, 26, 1655, 2, 1234],
#  [14, 416, 2246],
#  [195, 91, 3972, 61, 418],
#  [525, 30, 5232, 3643, 268, 1198, 5174, 25439, 369, 958, 50],
#  [11827, 1234, 90, 4161],
#  [5, 41, 7364, 2064, 184, 1824, 5, 92, 3945, 615, 579],
#  [561, 13, 10598],
#  [7125, 52816, 187, 874, 2775],
#  [684, 4, 5108, 7, 12, 923, 1, 52817, 712, 668, 5587, 140, 641, 4135, 528],
#  [1, 31028, 278, 65, 1673, 218, 871],
#  [50, 591, 67, 134, 1157, 17],
#  [653, 5588, 210, 4200],
#  [388, 190, 780, 38, 3509, 789, 186, 3261, 466],
#  [3617, 105, 109, 1347],
#  [144, 282, 14573, 26965],
#  [7, 33, 17185, 915, 588, 1831, 380, 727, 3896, 437],
#  [2, 36, 1541, 346],
#  [1162, 21985, 2432],
#  [10876, 14254, 1940],
#  [54,
#   2065,
#   42,
#   106,
#   1334,
#   31029,
#   32,
#   5,
#   4755,
#   1022,
#   2345,
#   1216,
#   3710,
#   533,
#   77,
#   781,
#   17,
#   211,
#   523,
#   255,
#   7,
#   317,
#   66],
#  [53, 446, 3695, 4178, 1455],
#  [2433, 1449, 18832, 2634, 456],
#  [40, 582, 33966],
#  [278, 65, 589, 654],
#  [13, 31030, 2211, 4317, 27, 17653],
#  [1, 190, 947, 6, 51, 9, 9],
#  [223, 3704],
#  [33967, 5382, 12378, 43, 8769, 3303, 7037, 156, 115, 185],
#  [34, 13434, 2590, 15],
#  [197, 158, 6, 1660],
#  [191, 225, 25440, 448, 134, 351, 38],
#  [8936, 2497, 825],
#  [7716, 545, 3812, 2632],
#  [61, 150, 37825, 24124, 285],
#  [6178, 398, 26, 596],
#  [39, 105, 276, 28854, 37826, 13971, 578, 6992, 168, 145],
#  [2664, 79, 1951, 360, 73476, 25],
#  [7, 937, 441, 312, 3246, 261, 7606],
#  [61,
#   131,
#   89,
#   948,
#   3166,
#   466,
#   308,
#   941,
#   557,
#   13,
#   3,
#   1048,
#   131,
#   1155,
#   3,
#   13,
#   1262,
#   2027,
#   63,
#   4210,
#   24,
#   146,
#   61],
#  [4136, 18235, 176, 5380],
#  [72, 67, 1465],
#  [241, 9110, 10736],
#  [67, 13972, 1966, 1742, 994],
#  [22, 132, 112, 2539, 107, 78, 73477, 80, 51],
#  [202, 2415, 56, 17, 3313, 422, 90, 117],
#  [315, 48, 2987, 1647, 172, 73478, 1065, 81, 2199, 3089],
#  [14, 4, 430, 5304, 224],
#  [4, 2227, 1024, 139, 1260, 81, 146],
#  [102, 9, 782, 7717, 547, 310],
#  [133, 432, 1219, 118, 339],
#  [22, 11997, 213, 25],
#  [1048, 257, 131, 59, 63, 818, 57, 935, 3167, 156, 401],
#  [190, 72],
#  [43479, 4337],
#  [1115, 53, 490],
#  [7998, 6896, 590, 357, 3292],
#  [57, 2079, 26, 212, 13973, 2346],
#  [2451, 6544, 286, 2125, 1276],
#  [73479, 5133, 1302],
#  [1099, 1140, 6004, 18236, 13689],
#  [563, 377, 15],
#  [726, 13974, 1935, 11498, 783, 224, 7, 42],
#  [16, 234, 46, 1, 3509, 319, 525, 507, 16738],
#  [12195, 52818, 641, 5941, 1140, 477, 1902, 272],
#  [2, 617, 10462],
#  [13690, 246, 819, 4783, 294, 13690, 1360],
#  [34, 1, 342, 1039, 1410, 2380, 8850, 4426, 8850],
#  [8, 15, 713],
#  [55,
#   3529,
#   7,
#   1674,
#   1859,
#   2552,
#   1395,
#   589,
#   2066,
#   192,
#   2438,
#   693,
#   558,
#   505,
#   417,
#   21058,
#   416,
#   12,
#   558,
#   297,
#   602,
#   121],
#  [33968, 63, 109, 20231, 528, 4521, 174, 3547, 52819],
#  [2337, 31, 1455, 19, 6402, 4674, 2344, 294],
#  [50, 4222, 425, 2931, 119, 1094],
#  [21, 435, 7, 1106, 1349, 447, 2297, 5747, 195, 258],
#  [73480, 522, 52820],
#  [34, 970, 1884],
#  [133, 3293, 14255, 4579],
#  [1330, 361, 544, 3157],
#  [45, 96, 17654, 96, 396],
#  [8062, 81, 717, 974, 2115, 203],
#  [246, 58, 26966, 1070, 222, 3235, 2169],
#  [50, 626, 78, 1281, 51, 190, 254, 79, 764, 2134],
#  [1318, 870, 141, 16739],
#  [450, 1594, 838, 25, 214, 1368, 4580],
#  [504, 4784, 3095],
#  [15559, 320, 204, 6778],
#  [33969, 2, 11, 244, 73481, 252, 73482],
#  [365, 1457, 636, 1019, 65],
#  [1185, 3689, 711, 97, 5],
#  [604, 424],
#  [73, 447, 3143, 212, 3727, 1520],
#  [1648, 21986, 43480],
#  [2686, 1678, 622, 518, 1879, 31031, 18237, 51, 4961],
#  [23, 539, 256, 569],
#  [153, 2445, 13435],
#  [21, 3025, 348, 8770, 348, 9],
#  [37, 283, 482, 2272, 33, 3247, 832, 720, 656, 262, 924, 2246],
#  [239, 2652, 941, 2092],
#  [1985, 17, 1540, 3585, 2223],
#  [45, 52821, 2837],
#  [7999, 6993, 9734, 404, 37827, 11, 1253, 799, 2851],
#  [3,
#   1712,
#   3200,
#   1971,
#   583,
#   656,
#   1074,
#   398,
#   1929,
#   741,
#   4,
#   22,
#   1524,
#   4218,
#   1074,
#   741,
#   131,
#   1636,
#   741,
#   371,
#   1636],
#  [171, 17655, 80, 9, 894],
#  [698, 2384, 9963, 3630],
#  [25441, 7884, 2781, 955, 369, 117, 440],
#  [9849, 170, 1140, 176, 3863],
#  [19, 1, 1061, 213, 79, 73483],
#  [70, 3402, 2883, 430],
#  [1896, 52822, 13975, 1713, 1545, 22, 609, 20232],
#  [226, 1297, 2762, 25],
#  [316, 18, 96, 1397, 41, 1701, 363, 41, 1911, 11021, 316],
#  [2, 11, 2164, 772, 322, 31032, 145, 73484],
#  [91, 10206, 1326, 15560],
#  [27, 11022, 259, 101],
#  [587, 352, 343, 871, 131, 2578, 587, 352],
#  [1061, 2900, 327, 190, 628, 828, 28, 3049, 26],
#  [1720, 5942, 2247, 1367, 4162, 238],
#  [15916, 73485, 1952, 3017, 73486, 1952, 3017, 401, 10, 840],
#  [301,
#   783,
#   85,
#   722,
#   471,
#   783,
#   286,
#   16740,
#   644,
#   1723,
#   3,
#   301,
#   85,
#   5971,
#   76,
#   3391,
#   3770,
#   3144],
#  [3314, 14256, 1228, 6, 298],
#  [3, 758, 1537, 957],
#  [549, 4522, 821, 3039, 2317, 1822, 1032, 3828, 6897, 1095, 2769, 132],
#  [3, 502, 8540, 9616, 28855, 802, 92, 149, 5, 4927, 14896],
#  [6361, 210, 252],
#  [3924, 253, 6034, 143],
#  [1, 1538, 35, 898, 1935],
#  [154, 569, 31, 7430, 708, 5, 146, 196, 305],
#  [1356, 156, 72, 214],
#  [57, 10, 2327, 349, 120, 14, 161, 52, 538, 1248, 4720, 25442],
#  [2488, 225, 3158, 15],
#  [2796, 407, 2796, 1530, 4756, 377, 580, 1093, 646, 242, 646, 646, 109],
#  [133, 432, 7074],
#  [327, 4017, 4, 2113, 476],
#  [2072, 2374, 870, 57, 5195, 22, 3508, 1452, 4564, 1452],
#  [3, 2, 1261, 684, 4077, 3411, 214, 4077, 3411, 817],
#  [2, 80, 51, 1014, 2783, 80, 2498],
#  [2273, 167, 142, 104, 1708, 18834],
#  [94, 139, 5719, 6940, 4549],
#  [1227, 3, 7, 46, 307, 141, 2825, 65, 1489, 5808],
#  [857, 2609, 900],
#  [2, 36, 610, 1058, 13436],
#  [43481, 43482],
#  [647, 1922, 3585, 311],
#  [173, 171, 19, 21987, 176],
#  [19, 1377, 2584, 238, 2797],
#  [38, 244, 1, 197],
#  [79, 633, 675, 41, 3618, 5068, 199, 120, 1234],
#  [13437, 165, 44, 21, 2650],
#  [401, 26967, 37828],
#  [2322, 32, 28],
#  [131, 1222, 519, 218, 9510, 62, 1416, 4375, 3168, 131, 37, 873, 4482, 62],
#  [5249, 8691, 867, 8465, 171],
#  [170, 1036, 37829, 364, 1309],
#  [3985, 38, 260, 890, 2194, 728, 63, 2590],
#  [420, 1905, 479, 10599, 299, 500, 3040, 31033, 479],
#  [116, 2796, 2613, 213, 63, 328, 20, 362],
#  [8851, 833, 102, 9617, 593],
#  [4, 348, 85, 8852, 11998, 3920, 618, 10600, 47, 417, 101, 10600, 437],
#  [8612, 446, 14897, 3530],
#  [46, 89, 57, 107, 190, 538, 52],
#  [6850, 2306],
#  [164, 140, 480, 65, 9],
#  [2, 1953, 281, 1799],
#  [2, 1900, 37830, 31034],
#  [302, 1222, 10207],
#  [37, 2140, 101, 3096, 8389, 1787],
#  [22, 313, 621, 1987],
#  [6, 36, 224, 1149, 683, 192, 31],
#  [195, 5720, 6101, 5972, 2451, 4615],
#  [46, 7126, 43483, 4945],
#  [27, 173, 3669, 8000],
#  [194, 3400, 4, 488],
#  [1, 584, 757, 6851, 300],
#  [14, 87, 1372, 67, 474],
#  [1736, 226, 5324, 44, 5324, 73487, 3228],
#  [3770, 1040, 69, 698, 233],
#  [13, 3340, 316, 278, 2157],
#  [1159, 32, 8198],
#  [369, 226, 39, 5, 5090, 167, 247],
#  [12, 292, 5008, 1525, 192, 113, 21059, 5910],
#  [18, 96, 843],
#  [19, 948, 101, 2013, 2750, 656, 42],
#  [49, 5054],
#  [1034, 55, 387, 141, 15561],
#  [98, 1327, 863, 12, 43484, 227, 2046, 15],
#  [501, 1023, 148, 26, 2322, 6470, 3392, 121],
#  [52823, 1524, 1503, 16, 33970, 25443, 33971, 494],
#  [805, 22956, 724, 172, 84, 238, 1255, 321],
#  [1162, 14256, 1243, 73488, 10463, 890],
#  [521, 305, 2, 980, 151, 1, 258],
#  [2363, 2392, 4240, 4757, 99, 1, 39, 20233, 26],
#  [6, 11, 1398, 2297, 138, 173, 484, 77, 8, 545, 18238, 5612],
#  [86, 1483, 11337, 4425, 301],
#  [16741, 239, 1353, 842, 6318, 1605],
#  [45, 239, 1057, 62, 5109, 466, 252, 466, 101],
#  [13, 4785, 201, 6362, 1896, 6647, 8771],
#  [85, 17, 1335, 619],
#  [45, 6648, 7607],
#  [689, 382, 1091, 6179, 197],
#  [98, 27, 1693, 37, 1349, 238, 150, 85, 678],
#  [17186, 58, 55, 208],
#  [195, 285, 1, 9301],
#  [9396, 619, 1558, 1707, 730],
#  [70, 402, 151, 74],
#  [2, 36, 186, 3294, 20, 4, 15],
#  [239, 3183, 1170, 1365],
#  [236, 21],
#  [1084, 1511, 632, 490],
#  [2, 720, 5779, 407, 258],
#  [891, 1217, 84, 369],
#  [1132, 170, 444, 18, 494],
#  [621, 73489, 5150, 281],
#  [6471, 177, 523],
#  [2416, 177, 283, 482, 249, 2416, 4393, 2023, 2622],
#  [104, 6472, 3478],
#  [6, 162, 4843, 1175, 2369, 1852, 158, 594, 870, 3813, 578, 605],
#  [1012, 17, 1035, 20, 501, 1837, 136],
#  [2219, 681, 323],
#  [1869, 1007, 2047, 1855, 289],
#  [1699, 44, 205, 631, 1294, 769],
#  [566, 480, 47, 73490, 1085, 166, 1965, 73, 63, 46, 1388, 21, 1085, 2156, 53],
#  [1853, 37831, 103, 2763],
#  [8613, 16742, 73491],
#  [7, 2, 52, 5304],
#  [12196, 102],
#  [1, 1627, 1404, 224, 814, 5252, 73492, 71, 38],
#  [2, 11, 1619, 1596, 845, 1207, 16316, 1941],
#  [6065, 1723, 2921, 101, 359],
#  [143, 67, 737, 5409],
#  [1027, 423, 752],
#  [284, 2077, 114, 3722, 5911, 71],
#  [5459, 623, 3393, 2, 994],
#  [64, 170, 12997, 2245, 21, 1930, 2099],
#  [11023, 1345, 104, 52824, 480, 1621, 378],
#  [916, 477, 2517, 2426, 35, 207, 652, 3974, 8063],
#  [3248, 6852, 36, 1771, 1578],
#  [420, 1780, 6, 9199, 5355],
#  [37,
#   1332,
#   164,
#   1141,
#   1547,
#   321,
#   425,
#   111,
#   321,
#   3,
#   494,
#   514,
#   18239,
#   3853,
#   6436,
#   2058,
#   8772,
#   411,
#   111],
#  [2, 44, 280, 411, 80, 31],
#  [2, 44, 52825, 4946],
#  [6242,
#   218,
#   2220,
#   37832,
#   43485,
#   1159,
#   588,
#   239,
#   134,
#   92,
#   347,
#   436,
#   26,
#   8001,
#   26,
#   2518,
#   87],
#  [137, 34, 4721, 3200, 893, 164, 3229, 183, 113, 3200, 893, 828],
#  [2, 73493, 4758, 5501, 1845],
#  [801, 2613, 1561, 78],
#  [7127, 3080, 380, 703],
#  [43486, 101, 333, 449, 317, 1106],
#  [7270, 805, 46, 5474, 22957],
#  [354, 2183, 24125, 100],
#  [2107, 9964, 34, 3639],
#  [5383, 734, 1407, 8, 631, 5943],
#  [50, 3028, 96, 63, 2137],
#  [1462, 1756, 692, 26968, 33972, 3069],
#  [276, 73494, 734, 539],
#  [1419, 19, 1270],
#  [188, 904, 11338],
#  [4801, 539, 412, 110, 1189, 182, 539],
#  [951, 77, 1587, 720, 48, 1277, 2948],
#  [16, 163, 620, 785, 1709, 2311, 31],
#  [2, 11, 215, 6279, 899, 278, 65],
#  [297, 52826, 20, 784, 31035, 395, 1101, 586, 52],
#  [2622, 64, 122, 73495],
#  [52827, 13438, 6994, 16317, 224, 4985, 21988, 825],
#  [1791, 418],
#  [2958,
#   10208,
#   8002,
#   10,
#   63,
#   3138,
#   27,
#   831,
#   1157,
#   1,
#   540,
#   134,
#   1775,
#   1806,
#   3631,
#   133,
#   26,
#   2635,
#   754],
#  [184, 31036, 95, 23],
#  [249, 12998, 1281, 15, 53, 258, 75, 3, 8],
#  [270, 62, 35, 1442, 25, 1548],
#  [2816, 250, 7365, 5, 6102, 17656, 211, 3138, 300, 76, 8466],
#  [504, 1976, 2884, 141, 3728, 15201, 1201, 12197, 1242, 1147],
#  [3, 5, 466, 673, 37833, 2290],
#  [2, 56, 99, 55, 5, 2324, 662, 698, 1192, 1679, 437, 296, 5, 1, 698, 773],
#  [1, 1627, 654, 1404, 796],
#  [16, 3, 233, 191, 16, 3, 935, 191],
#  [535, 92, 1555, 5212],
#  [2334, 537, 2334],
#  [9511, 4565, 11499, 4819, 1410, 2806, 11024, 4050, 1230, 932, 20234],
#  [25444, 400, 1901, 11828],
#  [5856, 3403, 26969, 1155],
#  [73, 1855, 284, 6588, 415, 3735],
#  [16, 191, 6941, 483, 3747, 31037],
#  [3, 3352, 1147, 679, 6005, 3262, 954, 3994, 193, 21989, 500, 8853, 822],
#  [3531, 4427, 29, 2548],
#  [1055, 9200, 706, 868, 43],
#  [231, 34, 35, 702, 1036, 1008, 209, 398, 182, 34, 4759, 37834, 1844, 121],
#  [11, 109, 35, 645, 153],
#  [3123, 7219, 7669, 162],
#  [7, 56, 103, 1490, 70, 92],
#  [3, 241, 73496, 24126, 37835, 14898, 24126],
#  [5410, 73497],
#  [945, 1533],
#  [534, 2304, 150],
#  [2, 509, 94, 476],
#  [14899, 93],
#  [1, 584, 1478, 328, 73498, 4163],
#  [5634,
#   423,
#   1230,
#   423,
#   221,
#   113,
#   1143,
#   154,
#   423,
#   1261,
#   423,
#   4441,
#   22958,
#   14,
#   1143,
#   669,
#   423,
#   241,
#   251,
#   4947,
#   105,
#   22958,
#   2227,
#   2703,
#   1555,
#   4032],
#  [4637, 98, 485, 32, 5, 15, 103, 2962, 5, 201, 7, 2962, 2962, 2827],
#  [4440, 9302, 3204, 881],
#  [2, 2621, 11, 186, 7366],
#  [2, 2922, 96, 1618, 27],
#  [1318, 207, 528, 4566, 73499, 2640, 254, 15202, 3263, 4483],
#  [49, 209, 111, 2982],
#  [522, 1, 1120, 313, 24127, 734],
#  [141, 1353, 2892, 356],
#  [1503, 10209, 1088, 21990, 82, 500],
#  [52828, 1052, 169],
#  [11190, 2006, 73, 2458, 338, 622, 463, 497, 4594],
#  [94, 73500, 6509, 52829],
#  [11, 304, 4121],
#  [961, 6853, 2095, 3452, 2095],
#  [91, 151, 1938, 506, 4241],
#  [115, 2553, 266],
#  [4738, 2452, 12571],
#  [43487, 3122, 1491, 340, 2877, 15, 4211],
#  [1443, 1436, 7718, 539, 4567, 245],
#  [4987, 129, 2245, 488],
#  [22959, 15562],
#  [27, 3242, 7947, 1054, 1723, 341, 323],
#  [4, 14, 766, 5809, 43, 831, 67, 275],
#  [141, 226, 3911],
#  [3,
#   115,
#   4,
#   11025,
#   2751,
#   4904,
#   7038,
#   845,
#   7719,
#   8614,
#   4033,
#   12198,
#   4484,
#   196,
#   783,
#   3,
#   228,
#   1113,
#   1912,
#   2776,
#   647],
#  [30, 781, 15, 40, 9512],
#  [231, 32, 1154, 572, 1606],
#  [104, 18240, 519, 302],
#  [9, 4034, 21060, 310, 10205, 2007],
#  [1, 2724, 2, 56, 208, 463, 10, 35, 3138, 602],
#  [375, 266, 221],
#  [33, 4242, 73501, 294],
#  [3, 115, 4293, 720, 1156, 2409, 364, 340, 1360],
#  [6180, 748, 9397, 748, 33973],
#  [4838, 47, 992, 1063],
#  [47, 2756, 16, 1251, 989, 149, 884],
#  [280, 656, 31038, 1947, 71, 1042, 312, 662],
#  [3115, 1687, 13439, 5325],
#  [3, 1401, 93, 381, 56, 10, 2769, 8, 62, 66],
#  [2, 449, 4442, 2063],
#  [551, 5, 6, 4, 155, 551, 729],
#  [1, 274, 1232, 40],
#  [3, 2015, 34, 616, 780, 6817, 112, 1098, 29, 4595, 445, 20235, 114],
#  [3771, 32, 225, 278, 340],
#  [195, 3619, 748, 646, 16318, 364],
#  [387, 970, 220],
#  [10, 242, 1860, 52830, 1, 602],
#  [2618, 794, 27, 8, 715, 1479, 453],
#  [2, 1117, 3059, 1548, 180],
#  [16, 191, 387, 425, 778],
#  [69, 1405, 1594],
#  [158, 383, 21, 271],
#  [1399, 3736, 2062, 4962, 52831],
#  [2381, 660, 15563, 7829],
#  [1467, 15, 73502, 1467],
#  [18835, 24, 173, 15],
#  [12379, 168, 73503, 1897],
#  [192,
#   12,
#   212,
#   10,
#   2,
#   56,
#   884,
#   2210,
#   1022,
#   1435,
#   10088,
#   257,
#   11500,
#   249,
#   270,
#   1285,
#   390,
#   73504,
#   4303,
#   583,
#   479,
#   5,
#   3925],
#  [1, 584, 712, 5973],
#  [1303, 8854, 336, 35, 1354, 506, 1303, 10464, 1062, 41],
#  [11339, 1007, 7431, 73505, 36],
#  [2, 271, 791, 894, 791, 158, 23],
#  [73506, 10341, 187, 874],
#  [98, 5134, 114, 11026, 859, 80, 820, 650, 1542],
#  [5, 298, 16, 67, 384, 2375, 35, 2100, 16, 2088, 890],
#  [12798, 527, 11340, 1204, 1458, 193, 182, 60],
#  [7830, 52, 1219, 1042, 73507, 304, 238, 129, 378, 2942, 385, 7554, 1038],
#  [246, 265, 2263, 593, 20],
#  [1463, 141, 1260, 132],
#  [4293, 91, 2526, 2007, 1792, 3304, 2221, 2562, 1205, 153],
#  [1845, 364, 296, 1915, 18836, 1185, 1492],
#  [1201, 5274, 1205, 81, 1201, 1719],
#  [879, 73508, 73509],
#  [788, 7769, 101],
#  [347, 2012, 10342, 5007, 65, 322],
#  [424, 4, 293, 3243],
#  [197,
#   6202,
#   271,
#   3476,
#   98,
#   3476,
#   83,
#   3476,
#   83,
#   98,
#   85,
#   1158,
#   3476,
#   98,
#   271,
#   2068,
#   1158,
#   6589,
#   3116],
#  [4123, 956, 844, 25],
#  [61,
#   127,
#   73510,
#   6136,
#   47,
#   5196,
#   2526,
#   2273,
#   8003,
#   509,
#   812,
#   16,
#   739,
#   3926,
#   2421],
#  [4928, 73511, 137],
#  [1967, 254, 4201, 1624, 4568, 71],
#  [641, 37836, 5, 279, 644, 88, 736],
#  [29, 38, 554, 1, 6, 554, 71],
#  [159, 681, 5780, 4],
#  [338, 178, 6006],
#  [54, 10, 74, 54, 700, 1394, 389, 215, 1474, 511, 46, 22],
#  [9, 6, 105, 1709],
#  [5671, 43488, 43489, 31039, 2039],
#  [101, 70, 73512, 1191, 131, 9],
#  [73513, 73514, 3436, 103],
#  [1389, 57, 2125, 3658, 1912, 4988, 1474, 82, 3532, 3572],
#  [88, 2328, 6510, 1544, 4318, 2104, 5672, 2064, 3542],
#  [5, 6363, 539, 423, 21],
#  [6280, 3814, 26970],
#  [65, 2296, 2174, 4801, 25445, 15917, 73515, 696, 11829],
#  [5460, 17187, 126, 462, 2763, 638, 2585, 348],
#  [16, 1580, 2080, 192],
#  [371, 2885, 16743, 832, 2892, 1474, 18837],
#  [18, 33, 15918, 14574, 9513],
#  [103, 563, 1586, 203],
#  [143, 2642, 41, 305, 523, 1999, 30, 99],
#  [1012, 2568, 480, 123],
#  [16744, 21991, 267, 6007, 4883, 9735, 28856],
#  [104, 623, 1341, 281],
#  [14, 10, 2665, 1744, 114],
#  [11, 268, 8692],
#  [7, 53, 676, 1162, 3609, 358],
#  [133, 1087, 3510, 1036, 209, 130, 632],
#  [2420, 2054, 2718, 466, 322, 279],
#  [165, 19, 8, 1653, 8937, 1099],
#  [45, 178, 20236, 178, 40],
#  [601, 1118, 1356],
#  [3490, 7075, 6473, 486],
#  [253, 397, 1141, 3632, 820, 8467],
#  [967, 1337, 2149],
#  [30, 6, 87],
#  [5534, 913, 52832, 50],
#  [174, 38, 1888, 1455, 1330, 3412],
#  [501,
#   103,
#   930,
#   786,
#   15,
#   76,
#   685,
#   73516,
#   99,
#   27,
#   2631,
#   14575,
#   1236,
#   2337,
#   32,
#   4,
#   857,
#   6688,
#   6729,
#   97,
#   428,
#   1395,
#   862,
#   15],
#  [1436, 7831, 530, 86],
#  [27, 965, 189, 423, 2088],
#  [105, 294, 386, 6281, 2141, 5197, 8541, 22, 4004, 174],
#  [1437, 90, 3131, 1505],
#  [1131, 2135, 102, 86, 2228, 2386, 3413],
#  [4353, 16745, 164, 2432, 397, 8199, 274, 1292, 378],
#  [2, 11, 1056, 29, 389, 239, 73, 189, 1394],
#  [110, 1847, 676, 10, 74],
#  [181, 508, 73517, 73518, 5, 21],
#  [314, 3853],
#  [17, 35, 2304, 3379, 824, 699, 1469, 344],
#  [244, 13213, 13976, 12572, 51, 405, 219],
#  [67, 25, 4638, 21, 66],
#  [3, 2, 126, 6008, 18838],
#  [1661, 674, 749, 2352, 14257],
#  [1332, 239, 3630, 239, 3630],
#  [25446, 73519, 2842],
#  [1313,
#   1116,
#   1690,
#   496,
#   3189,
#   877,
#   5461,
#   6730,
#   11999,
#   496,
#   839,
#   16,
#   12,
#   22,
#   258],
#  [26971, 64, 664],
#  [20, 3560, 297, 7555, 5, 146, 20, 73520, 1508, 470],
#  [3380, 55, 21061, 188, 5032, 5069, 1915, 10601, 873],
#  [2452, 177, 3031, 1161],
#  [85, 4, 3190, 619],
#  [30, 2017, 399, 10602, 498, 513, 28, 1517, 26972, 4078, 593, 737, 399, 8542],
#  [2211, 2563, 155, 293, 701, 3105],
#  [2026, 10877, 2564, 1852, 345, 1805, 3018],
#  [13, 1333, 394, 304],
#  [6364, 741, 1694],
#  [753, 18, 284, 3341, 415, 3527, 758, 1644, 10343, 548, 7, 19, 7, 39, 745],
#  [28857, 18839, 5810, 3620],
#  [231, 2557, 4485, 174],
#  [150, 18, 1, 25],
#  [787, 3414, 236, 7128, 236],
#  [4051, 91, 301, 6009, 92],
#  [9, 234, 1, 573, 1, 760, 43490, 11501, 2000],
#  ...]

# %%
train_matrix = sequence.pad_sequences(seq_train, maxlen=max_len) ##PADDING SHORTER SEQUENCE TO GET A DEFINED MATRIX
train_matrix.shape
# Out:
# (979591, 29)

# %%
seq_test = tok.texts_to_sequences(x_test)
seq_test
# Out:
# [[959, 68, 535, 376, 489, 1044],
#  [570, 7557, 125, 1790],
#  [534, 132, 77, 2131, 137],
#  [439, 12517, 102],
#  [891, 6338, 3888, 138, 1319, 101],
#  [1056, 1175, 4015, 10507, 1458, 7242],
#  [100436, 65, 67724, 173, 345, 676, 68, 550, 210, 67724, 3791, 19444, 639],
#  [459, 2, 100],
#  [24, 387, 49156],
#  [292, 15092, 25210, 60, 499],
#  [18, 8, 1922, 606, 3587, 16412, 1672, 324, 5646, 8, 15640],
#  [250, 26596, 2590, 188, 8458],
#  [403, 813, 11742, 285, 1508, 1876],
#  [653, 958, 58],
#  [558, 1601, 3, 27, 2288, 83, 1921, 3, 12, 3, 380],
#  [4, 3220, 151],
#  [6259, 4576, 1682, 15141, 7452, 440],
#  [259, 40, 762, 15, 11],
#  [137, 2279, 495],
#  [11, 454, 648],
#  [601, 45, 414, 5344, 414],
#  [1122, 5221, 14800, 228, 321, 36, 386, 694, 10787],
#  [1480, 8532, 5700],
#  [63, 459, 3447, 10306, 1327, 456],
#  [22452, 20705, 646, 4815, 3060],
#  [6156, 74, 339, 230, 10, 4079, 1416, 576, 622, 907, 656, 334],
#  [141, 17864, 2443, 2673, 3175],
#  [2, 1659, 8275, 1076],
#  [2945, 123, 17107],
#  [2586, 248, 1552],
#  [209, 270, 56, 1, 74],
#  [6635, 3915, 4, 4593, 6635, 4, 11, 113, 4, 261, 6635, 745],
#  [27, 486, 2377, 125, 4288],
#  [13, 26, 14, 339, 56, 4625, 345],
#  [4567, 3625, 3320, 7184, 352],
#  [49, 2200, 6302, 3903, 1680, 7291],
#  [2327, 664, 636, 95, 43, 16622, 43, 140],
#  [125, 888, 20],
#  [3, 2729, 203],
#  [7593, 8555, 401, 98, 1637],
#  [69, 18, 1, 454],
#  [14, 132, 2711, 628, 3041, 1518, 978, 9769, 8086, 22361, 2711, 2715, 208],
#  [2377, 129],
#  [17, 4803, 3278, 702, 2658, 3012, 588, 2658, 422, 2121, 3, 63, 3012],
#  [1331, 569, 2653, 19912, 555],
#  [902, 17, 54, 2970],
#  [849, 63, 5153, 163, 3618],
#  [23694, 469, 219],
#  [2012, 36947],
#  [515, 13102, 9129, 70, 506, 1063],
#  [29, 616, 120, 92, 992, 382, 493, 200, 709],
#  [5, 119],
#  [1006, 53, 610, 1058, 1675],
#  [2, 24, 1721, 38, 1370, 4244, 71],
#  [38876, 624],
#  [6, 892, 7701, 34486, 1203],
#  [1152, 56, 1084, 514, 2156, 647, 91, 865, 1568, 12],
#  [844, 446, 7382, 7434, 217, 35, 8046, 3433, 646, 10988],
#  [4800,
#   254,
#   86,
#   506,
#   59,
#   18898,
#   1001,
#   1172,
#   199,
#   4800,
#   6509,
#   9842,
#   2395,
#   479,
#   5,
#   2538,
#   7813,
#   150278,
#   16876,
#   2557,
#   1150,
#   4,
#   598],
#  [98, 485, 184, 61, 983, 3254],
#  [26617, 20851, 428, 347, 221, 2617, 2058],
#  [11823, 183, 2578, 450, 116, 52],
#  [20, 17, 13793, 1035],
#  [640, 351, 880, 568, 1, 7670],
#  [45, 25622, 1307, 5036, 25622, 6486, 5036],
#  [1225, 2560, 266, 5135, 735, 266, 270, 2670],
#  [5, 78, 7052, 51, 3722],
#  [124, 366, 314, 397, 157, 912, 186, 648],
#  [748, 106577],
#  [1186, 6398, 1120, 138, 5978, 3415, 3031],
#  [16935, 276, 229],
#  [1, 405, 51, 1305, 190],
#  [9965, 282, 82, 179],
#  [24, 356, 53, 132, 2299, 1258],
#  [184, 22552, 3219, 2874, 3581, 63, 729, 828, 66],
#  [13, 1601, 3970, 927, 686, 3970, 958, 2557, 16108, 136, 4441, 958, 6028],
#  [71, 34670, 3267, 101],
#  [16, 62, 785, 16, 62, 2965, 26, 3294, 4, 9220],
#  [202, 1115, 765, 822, 2788],
#  [726, 1045, 15748, 12010],
#  [1876, 391, 1755, 1165, 13377, 6165, 2884, 132, 3728],
#  [92, 48, 1347],
#  [5456, 387, 2622],
#  [414, 295, 250, 83, 6, 9458],
#  [154,
#   718,
#   23,
#   1224,
#   257,
#   1575,
#   1962,
#   1959,
#   200,
#   2598,
#   2007,
#   6337,
#   6095,
#   2565,
#   257,
#   28,
#   979,
#   1156,
#   15712,
#   136],
#  [16, 128, 3816, 942, 9553, 3694, 2667, 5340, 598],
#  [49, 5, 21, 22961, 44, 5, 22961, 2020, 79, 258],
#  [195, 17, 2184, 397, 2132, 141, 1265, 91],
#  [49,
#   375,
#   105,
#   1168,
#   1442,
#   4366,
#   6809,
#   2361,
#   2741,
#   814,
#   5412,
#   1491,
#   67,
#   325,
#   3031],
#  [27, 1534, 2724, 451],
#  [13, 1531, 293, 1317, 1102, 350],
#  [3119, 1264, 753, 942, 12562, 13531, 2715, 37, 1008],
#  [51, 22, 2794, 829, 13319, 3645],
#  [6, 827, 973, 4974, 3075, 12301, 2207],
#  [10797, 6535, 103, 797],
#  [11, 3115, 247, 1406, 2690, 11696, 245],
#  [6, 1681, 158, 2263],
#  [3251,
#   129,
#   433,
#   14127,
#   1458,
#   1077,
#   4527,
#   193,
#   425,
#   374,
#   157,
#   1987,
#   8,
#   6196,
#   6196,
#   8,
#   19826,
#   6196,
#   8,
#   6005,
#   7323],
#  [117, 1791, 1935],
#  [133, 12450, 1478, 1280],
#  [1537, 1161],
#  [23, 1, 2383, 579, 572],
#  [2, 14945, 911, 74, 4],
#  [314, 8039],
#  [3670,
#   2716,
#   10,
#   6829,
#   1780,
#   2716,
#   10,
#   3287,
#   107,
#   66,
#   66,
#   68,
#   20,
#   376,
#   489,
#   202,
#   1656,
#   1604,
#   77,
#   5474,
#   78,
#   1047,
#   331],
#  [11342, 7608, 14661, 1074, 3320, 161],
#  [65, 110, 2383, 764, 1293, 302, 1111],
#  [458, 12144, 5021, 23],
#  [291,
#   18,
#   205,
#   308,
#   329,
#   716,
#   6413,
#   329,
#   737,
#   137,
#   205,
#   32,
#   1304,
#   369,
#   35,
#   5230,
#   966,
#   1395,
#   79],
#  [155, 11, 633, 4, 11669],
#  [2, 3123, 2076, 7545, 158],
#  [1227, 12169],
#  [2271, 7364, 5, 67, 93],
#  [805, 172, 1975, 305],
#  [1845, 163, 63, 2115, 4860, 569],
#  [32, 5, 5842, 969],
#  [156, 59, 84],
#  [4314, 1805, 115, 81],
#  [20154, 772, 16597, 9777],
#  [50, 961, 863, 247, 147, 7, 730],
#  [32, 481, 38],
#  [348, 4175, 2016, 1267, 304, 2016, 404],
#  [600, 714, 660, 135],
#  [1858, 9, 1767, 889, 779],
#  [150, 497, 245, 4742, 84, 2773],
#  [15951, 43597],
#  [3, 7988, 8474, 2544, 240, 131, 548, 503, 989, 161, 10737, 136],
#  [71,
#   284,
#   235,
#   1541,
#   658,
#   298,
#   54,
#   616,
#   34351,
#   10347,
#   4924,
#   51,
#   679,
#   235,
#   54,
#   351,
#   38,
#   11],
#  [1770, 91, 781, 12970, 2543, 8840, 2884],
#  [12074, 2309, 3654, 148, 1572, 28],
#  [2639, 33, 25228, 10048],
#  [7, 244, 728, 35, 567, 831, 406],
#  [923, 265, 4929, 4929, 43, 3, 598, 367, 42, 686],
#  [425],
#  [151,
#   3257,
#   959,
#   68,
#   39837,
#   466,
#   576,
#   75,
#   576,
#   619,
#   147,
#   959,
#   68,
#   421,
#   2571,
#   374],
#  [1706,
#   495,
#   518,
#   755,
#   1139,
#   2673,
#   2299,
#   1258,
#   6657,
#   416,
#   468,
#   141,
#   3652,
#   439,
#   667,
#   220,
#   4965,
#   302],
#  [1, 2214, 53, 920, 1350, 746],
#  [138, 1409, 355, 1478],
#  [338, 19, 4505, 2942, 3963, 3064, 4743],
#  [268, 4866, 4690, 40, 9207, 6910],
#  [3, 200, 225, 92, 8240],
#  [54402, 21616, 33154, 528, 804, 11, 11571, 10, 840],
#  [2430, 25100, 678],
#  [38, 780, 11249, 959, 3009],
#  [144, 1200, 784, 1616],
#  [291, 91, 5957, 1601],
#  [291, 46, 42, 52, 338, 340, 12081, 36, 2748, 481, 618, 689, 923, 35, 136],
#  [2005, 54, 6, 78, 21, 33, 426, 8285, 31],
#  [711, 642, 1010, 668, 11223, 213, 1100, 1529],
#  [2945, 1256, 3116, 16592],
#  [33, 19651, 319],
#  [40, 12101, 11361],
#  [3, 194, 417, 29],
#  [842, 1542, 113, 134],
#  [2025, 3457, 989, 2537, 618],
#  [18901, 1821, 597, 1, 12680],
#  [195, 264, 1880, 471],
#  [25179, 445, 2, 229, 164, 1869, 3455],
#  [75, 62519, 1629, 218, 147, 1602, 147],
#  [37, 1, 92, 405, 763, 7708],
#  [2, 105, 528, 814, 319],
#  [446, 3717],
#  [1627, 1515, 11, 3285, 185, 1719],
#  [11990, 4254],
#  [145, 383, 193, 383, 44],
#  [409, 13, 8160, 29, 26],
#  [4425, 193, 3363, 1559, 5637],
#  [23, 5310, 6046],
#  [36, 461, 386, 1073, 1918, 852, 58637, 41462],
#  [246, 11, 14124, 6996],
#  [26, 3, 970, 4430, 2472],
#  [17666, 5650],
#  [1, 1374, 423, 26917],
#  [13041, 1489, 2567, 446, 172, 36],
#  [1122, 1587, 3259, 4008, 17236],
#  [2028, 531],
#  [3081, 538, 1, 578, 1445],
#  [54, 7853, 720, 17, 485, 1572, 1663, 1417, 1216],
#  [688, 256, 60, 681],
#  [373, 47, 428],
#  [1724, 3825, 3737, 6122, 637, 458, 112, 2919],
#  [8547, 97, 5, 334, 761],
#  [1, 2812],
#  [52, 39, 15540, 8706, 18, 1042, 265, 121],
#  [10510, 455, 6471, 672, 6569],
#  [1658, 5590, 607, 43155, 1712],
#  [5191, 4589],
#  [14, 1127, 4250, 1840],
#  [411, 216, 33, 1733],
#  [2, 2311, 31, 4030, 778, 163],
#  [542, 6592, 956, 1931],
#  [5995, 129, 1301, 1271, 1400, 3652],
#  [16, 12, 22, 675, 3189, 3792, 20088, 52681],
#  [1, 25, 519, 218, 507, 1098],
#  [366, 801, 191, 1290, 1394],
#  [33, 1911, 845],
#  [13538, 19, 5890, 113, 5283, 1365],
#  [5, 632, 1872, 853, 17, 485, 39, 93],
#  [787, 403, 197],
#  [202, 67, 17, 16, 1044, 93, 1969, 9083],
#  [416, 255, 1429, 48, 1137, 60, 1052, 849, 14178, 63, 13103, 68, 2779, 1248],
#  [226, 9077, 44400],
#  [597, 157, 32, 1887, 1200, 17, 698, 1349, 19587, 11],
#  [1452, 673, 4785, 255, 1, 109, 1191, 5, 149, 100],
#  [1760, 106, 6, 51, 2973, 234, 1576, 607],
#  [301, 33, 4788],
#  [4554, 25506, 537, 303, 804],
#  [13, 9662, 1518, 97, 32, 5, 1518, 35, 1268],
#  [2, 985, 1133, 1930, 36, 1855, 258],
#  [152, 78, 50, 230, 31, 4452, 82, 723, 1479, 5236],
#  [25, 33, 4713, 73, 13, 22, 131, 5884, 2270, 601, 696, 3, 210, 93],
#  [25,
#   592,
#   217,
#   5797,
#   580,
#   955,
#   216,
#   1076,
#   863,
#   868,
#   759,
#   1079,
#   66,
#   68,
#   30,
#   2115,
#   466,
#   25,
#   2922,
#   5,
#   3679,
#   216,
#   1392,
#   580,
#   955,
#   267,
#   216,
#   526,
#   11032],
#  [195, 1291, 177, 89, 4796],
#  [861, 2364, 9, 3046, 196],
#  [54715, 20368, 1537, 314, 246, 1415],
#  [20330, 14772, 7, 527],
#  [409, 32, 74, 52, 1150, 758, 202, 2058, 679, 1740, 306],
#  [34448, 176, 2402, 780, 1009, 152],
#  [37, 122, 676, 3, 121],
#  [468, 349, 65, 330, 850, 133, 850, 519, 218, 9],
#  [10126, 3295, 79, 2808, 435, 11383, 1067, 2, 435, 1166, 1067],
#  [272, 616, 312, 104, 657, 1070, 1174, 1772, 3925],
#  [8, 2281, 1605, 15317, 1987, 6544, 1513],
#  [185, 689, 957, 690, 378],
#  [564, 106, 4784, 9561],
#  [269, 462, 132521, 396, 12739],
#  [4012, 27522, 106, 4495, 1156, 1407, 7899, 2901, 1126, 23],
#  [128, 2954, 970, 1560, 1864, 9, 1042, 782, 880, 310],
#  [2072, 583, 1434, 35, 19500],
#  [1440, 17, 226, 119, 68, 17, 226, 119, 743, 4502, 664],
#  [149, 1429, 1158, 26216, 1116, 238, 456, 956, 12, 1426, 217],
#  [395, 2140, 2740],
#  [233, 543, 277, 4450],
#  [2,
#   11,
#   481,
#   2479,
#   746,
#   54,
#   3340,
#   41,
#   966,
#   179,
#   3092,
#   563,
#   1539,
#   2479,
#   888,
#   1,
#   584,
#   2479,
#   746],
#  [13,
#   3,
#   241,
#   438,
#   993,
#   386,
#   3805,
#   10272,
#   7945,
#   113,
#   5594,
#   10272,
#   54,
#   1247,
#   9756,
#   4916,
#   10272,
#   4916,
#   940],
#  [521, 305, 2, 24, 93, 381, 337, 7560, 2204],
#  [14, 3958, 4, 20, 734, 117, 461, 64, 1842],
#  [400, 506, 5561, 28580],
#  [508, 5083, 144],
#  [6, 39760, 270, 56, 1537, 96],
#  [1132, 7995, 2394, 1, 10, 7, 86, 28, 3, 260, 121],
#  [99, 13, 426, 15, 10306, 5757, 847],
#  [6937, 606, 127, 3832, 14757, 364],
#  [681,
#   1754,
#   561,
#   30,
#   13378,
#   7258,
#   267,
#   604,
#   638,
#   17493,
#   1754,
#   1126,
#   2526,
#   1732],
#  [4, 13, 2721, 2818, 79, 285],
#  [172, 216, 1278, 1050, 496, 5529, 5, 204, 1079, 535, 310, 7114, 128, 258],
#  [6, 169, 12, 25, 1115, 70, 117, 2491, 205],
#  [1384, 843],
#  [575, 2507, 6926, 12308, 6926, 12308, 121],
#  [14, 4, 40, 46473, 13175, 2370, 10811, 11846, 1100, 5],
#  [1694, 16066, 1390, 8146, 2378, 2799, 1925, 280],
#  [19560, 6, 4133],
#  [2332, 552, 55, 141, 10462],
#  [71, 277, 7, 2, 1207, 1207, 928, 262, 4672, 71, 1947, 189, 343, 449, 592],
#  [354, 6394, 26, 5141, 12497, 14605, 12900],
#  [14, 367, 292, 9, 629],
#  [1429, 126, 284, 319, 71, 6219, 279],
#  [10361, 409, 59, 238, 7635, 124, 85, 157, 12763],
#  [3490, 19, 49280, 3844, 20, 795],
#  [37, 976, 1209, 282, 5733, 1816],
#  [124, 1042, 78, 1070, 2427, 12, 1035, 24150, 7323],
#  [2, 4808, 5076, 237, 4808, 5370],
#  [5, 5175],
#  [6, 1, 2629, 35, 10851, 1458, 288, 9939, 20251, 1700, 822],
#  [250, 2839, 13149, 1952, 368],
#  [10206, 1001],
#  [6, 2707, 3036, 630, 107, 525],
#  [9170, 19854, 465, 1011, 4145],
#  [14, 4, 454, 203],
#  [298, 7332, 346, 346, 7332, 744, 744, 7332, 15, 15, 534, 7332, 298],
#  [24, 1047, 888, 91, 136],
#  [8643, 11, 355, 5200, 1115],
#  [365, 1239],
#  [983, 71, 2, 13740, 1211, 1556, 190, 452, 276, 35728],
#  [4963, 1789, 392, 828, 3348],
#  [1839, 67, 253, 1444, 82],
#  [318, 2134, 16, 15],
#  [2, 2298, 1107, 5370, 158, 1757],
#  [3, 241, 623, 4496, 2669, 1486],
#  [9832, 641, 34, 922, 15],
#  [8, 2, 19, 968],
#  [532, 9923, 1096, 3160, 211, 621, 179, 4096, 1028, 3094, 28],
#  [8602, 2607],
#  [],
#  [312, 173, 12323, 1385, 1263],
#  [2390, 1623, 4860, 11030, 4133, 1219, 4885, 2123, 205, 399, 763],
#  [2877, 17980, 3879, 3169],
#  [157, 713, 214, 397, 28],
#  [2, 1114, 70, 410, 191, 16],
#  [99908,
#   99909,
#   3512,
#   689,
#   989,
#   3882,
#   28631,
#   2507,
#   17886,
#   1336,
#   8224,
#   2924,
#   5691],
#  [490, 162, 62, 53, 399, 8945, 1, 2667, 3254],
#  [3222, 5529, 22, 2419, 870, 1261, 6741, 213, 5109, 62],
#  [16, 349, 1173, 3833, 165, 526, 9],
#  [21, 1583, 429, 35840, 824],
#  [351, 38, 166, 7025, 38, 415],
#  [3136, 1308],
#  [142, 221, 14493, 2887],
#  [597, 666, 985, 7, 1127],
#  [385, 1909, 282, 257, 1102, 3308, 841],
#  [3709, 8041, 426, 227, 1950, 23],
#  [3603, 70, 59879, 8414, 650, 1716],
#  [3, 22, 216, 1007, 7839, 294, 3959, 3439, 331],
#  [13, 5857, 473, 411, 80, 6, 725],
#  [542, 24, 184, 810, 472],
#  [142, 2072, 608, 210, 82291, 880, 52, 343],
#  [508, 6124],
#  [3860, 129, 1301, 1457],
#  [1332, 2095, 5932, 1085, 2095, 5932, 3496, 31951, 238, 14730],
#  [4034, 234, 1341, 1161, 469, 6715, 71],
#  [5815, 711, 1890, 249, 426, 9512, 10493, 22089, 711],
#  [1264, 25852, 3308, 59, 54, 4999, 7200, 7306, 702, 378],
#  [2415, 127, 690, 451, 202],
#  [4653, 847, 301, 2577, 46, 1, 199, 1800, 3645, 8649, 925, 6, 27648],
#  [2215, 13591, 21, 1930],
#  [346, 1167, 947],
#  [2, 4406, 1368, 43, 1368, 35, 275, 4, 3871],
#  [128, 9270, 9874, 9, 1745, 111, 686, 18, 127, 732, 9],
#  [993, 12535, 26784],
#  [782, 311, 321, 993, 6536, 3091, 3436],
#  [27,
#   965,
#   82,
#   33,
#   857,
#   78,
#   559,
#   550,
#   7455,
#   3819,
#   282,
#   1136,
#   3611,
#   46,
#   72,
#   5204,
#   223,
#   638,
#   5069,
#   3306],
#  [144, 6566, 744, 58, 10, 1013],
#  [347, 776, 1263, 496],
#  [375, 545, 6390],
#  [882, 1709, 1863, 107, 265, 2401],
#  [41, 16, 3502],
#  [2928, 1618, 36],
#  [8162, 11, 1414, 72, 1628],
#  [575, 59, 1348, 1114, 1495, 1395],
#  [2, 372, 180, 862, 893, 3852, 479],
#  [],
#  [243, 477, 1001, 8735, 71],
#  [250, 6460, 4322, 1352],
#  [487, 838, 390, 95],
#  [9309, 168, 122, 144, 736, 12601, 2283],
#  [49, 2542, 24, 401, 1835],
#  [1711, 581, 55, 36, 3778, 108, 71481, 9967],
#  [3, 597, 912, 1842, 11, 15],
#  [3, 842, 73, 2131, 506, 12],
#  [44720, 61999],
#  [104, 1264, 1326],
#  [2863, 895, 25, 26],
#  [4, 194, 233, 4868, 1, 6022, 17, 2209, 751, 494, 238, 2553, 159],
#  [1743, 1294, 1771, 33, 33, 1562],
#  [916, 828],
#  [1045, 1358, 2501, 34, 86, 5232, 663, 2249, 1227, 9],
#  [396, 70, 12, 127, 65, 3714, 5, 785, 12, 56],
#  [355, 766, 1589, 3657, 90, 42],
#  [342, 1, 5, 619, 1517, 56, 247, 300, 160, 196],
#  [7958, 923, 1589, 4776, 982, 1781, 7036],
#  [13016, 5725, 1355, 16, 39, 909, 158],
#  [50, 30, 246, 1328, 394, 378],
#  [959, 68, 30, 5828, 421, 2022, 678, 3842, 67, 437],
#  [1812, 579, 228, 8472, 126, 1128],
#  [601, 45, 718, 544, 252],
#  [104, 1317, 1031, 7177],
#  [127, 56, 99, 1824, 35, 467, 106, 2542],
#  [17, 1829, 26395, 2412, 362, 62, 37, 7192, 75, 2040, 100, 800, 4132],
#  [4486, 410, 69, 5, 602, 1564, 199, 437, 238, 721, 6183, 1028, 988, 86, 66],
#  [8316, 17573, 2688],
#  [32, 1868, 836],
#  [16, 1, 1199, 828, 3348, 10],
#  [3063, 117, 1314, 739, 78, 271, 3, 77, 18410, 152, 48, 1062],
#  [183, 650, 10],
#  [12997, 50],
#  [1542, 18105, 116],
#  [638, 579, 5484, 3838, 747, 6711],
#  [7, 1, 25, 894, 3493, 216],
#  [479, 802, 3788],
#  [4,
#   428,
#   5,
#   5564,
#   58,
#   2227,
#   440,
#   125,
#   202,
#   58,
#   34,
#   898,
#   28,
#   76,
#   492,
#   300,
#   366,
#   123,
#   58,
#   1400],
#  [410, 2635, 2368, 416, 249],
#  [98, 485, 1746, 4, 1806, 16, 6681, 8872, 39, 4941, 5127],
#  [1, 186, 3882, 428, 2457, 428, 3681, 428, 3767, 3603, 218],
#  [155, 58, 626, 858],
#  [3040, 608, 26006],
#  [133, 4015, 10, 396, 130, 701, 222, 170, 267, 1373, 702, 267],
#  [1894, 538, 190, 132, 112, 6961],
#  [53, 578, 369, 215],
#  [72, 1273, 9293, 556, 261, 35, 2541, 174, 9],
#  [283, 482, 69, 18, 583, 13154, 3915, 2416, 177, 629, 25467, 50846],
#  [396, 10, 609, 884, 154, 1333, 91, 306],
#  [4, 3979],
#  [61,
#   904,
#   59,
#   394,
#   304,
#   2978,
#   709,
#   304,
#   792,
#   2515,
#   93,
#   10596,
#   2515,
#   376,
#   489,
#   61,
#   66,
#   68,
#   13,
#   20,
#   39],
#  [14, 3122, 141, 303, 482],
#  [6, 3077, 51],
#  [110, 803, 722, 9, 1932, 848],
#  [1405, 100, 429],
#  [733, 327, 1951, 13742, 82, 15, 7866, 70, 26, 738, 3017, 398, 225, 530],
#  [606, 2403, 421, 8, 82, 32, 563, 1077, 783, 136],
#  [1797, 3030, 4389, 12905, 591, 99],
#  [2, 165, 19, 9806, 578, 749, 215],
#  [2067, 4148],
#  [1488, 850, 3826, 8, 193, 4046, 6743, 321],
#  [2497, 87, 23693, 96, 311, 14, 775, 311, 84, 3418, 2497, 133],
#  [30, 54, 69, 6, 65, 5, 13],
#  [1, 703, 352],
#  [694, 244, 22, 1541, 416, 12, 1, 39, 235, 184, 5727, 428],
#  [2793, 53481],
#  [394, 55, 398, 4, 10, 146, 3827, 1140, 398, 4, 5677, 4995, 141, 57],
#  [2609],
#  [109,
#   2757,
#   220,
#   1849,
#   113,
#   163,
#   158,
#   675,
#   7851,
#   1747,
#   2100,
#   13308,
#   23741,
#   1393,
#   15578,
#   1747],
#  [1436, 3835, 5874],
#  [43, 123, 25280],
#  [19630, 455, 414, 455, 1069],
#  [60, 508, 827, 2181, 3729, 3345],
#  [8, 62, 81, 2428],
#  [100, 1516, 321, 1388, 517, 1714, 600],
#  [269, 181, 1634],
#  [1322, 40028, 42, 637],
#  [31013, 40174, 15],
#  [110, 2591, 236, 292, 1168, 2056, 822],
#  [23493, 304, 2118],
#  [26847, 7978, 214],
#  [3592, 38, 71, 13976, 12572, 277, 681, 5387, 351, 38],
#  [232, 319, 71, 189, 731, 2109, 117],
#  [4591, 10644, 106, 6412],
#  [20097, 1283, 7365, 73, 428, 1037, 190, 2532, 3463],
#  [24, 61, 556, 20, 2648, 332],
#  [2168, 378, 1017, 462, 3630],
#  [690, 29019, 2173, 93],
#  [91, 1761, 2370, 1938, 1117, 662],
#  [14094, 591, 11276],
#  [1108,
#   11026,
#   167,
#   2872,
#   1375,
#   10,
#   58,
#   324,
#   362,
#   5241,
#   610,
#   411,
#   80,
#   918,
#   2594,
#   567],
#  [615, 7888, 21, 105],
#  [5, 753, 3, 697, 528, 4057, 35, 3138, 602],
#  [1020, 351, 26, 42, 13241, 5562, 16405, 7528, 351, 87, 42, 211],
#  [111, 9146, 1070, 1742, 587],
#  [1123, 4641, 8394, 2646],
#  [450, 151233, 1288, 3554, 2205, 687, 337, 1263, 537],
#  [1918, 6280, 114, 542, 1, 25],
#  [816, 712, 10786, 2621, 65, 120, 1206],
#  [34, 7122, 1113, 1919],
#  [7368, 1197, 296, 1474, 36564, 6823, 3762],
#  [165, 244, 1274, 1464, 576, 1037, 2375, 517, 208, 644, 135, 165, 3066],
#  [6661, 4, 13, 10597, 2071],
#  [196,
#   11085,
#   5061,
#   18112,
#   3722,
#   16290,
#   1200,
#   98,
#   5061,
#   1006,
#   4233,
#   5163,
#   11598,
#   12,
#   1663,
#   5748],
#  [30, 36, 1258, 416, 468, 36, 525],
#  [1, 96],
#  [37, 6796, 510, 4834, 13591, 68],
#  [29282, 1425, 1888, 693],
#  [2, 11, 221, 23562, 135],
#  [337, 16333, 56, 13, 4227, 242, 1115, 4152, 9076, 531],
#  [39, 36, 160, 196, 326, 278, 44],
#  [3, 2100, 15482, 17515, 7227, 248, 2601, 541, 471],
#  [113855],
#  [29, 659, 59, 716, 992, 200, 583, 7803, 11578, 102, 1759, 884, 1047],
#  [206, 47, 207, 1527, 1712, 134, 799, 37, 10],
#  [205, 265, 317, 185],
#  [166, 1472, 201, 71187],
#  [16, 62, 22, 7875, 2677],
#  [371, 1, 202, 2304, 3379],
#  [5046, 2791, 747, 177],
#  [410, 655, 1685, 6712, 588, 328, 602, 27, 67, 602],
#  [10565, 160, 2012, 15133, 44],
#  [1, 3608, 7331, 3526, 20334, 107],
#  [1, 1236, 335, 464],
#  [460, 1482, 109, 1168, 48, 1137],
#  [1358, 299, 568, 104, 299, 591, 2636, 9674, 2076],
#  [478, 4, 40],
#  [11632, 1464, 6, 794, 8335, 2523],
#  [59, 41, 6179, 274, 267, 484],
#  [14, 1024, 4, 1498, 1492, 1722, 228, 604],
#  [2, 52, 83],
#  [165, 216, 20, 3068],
#  [18, 287, 5407, 868, 441],
#  [66030, 294],
#  [2, 372, 330, 44, 507],
#  [393, 22, 276, 29, 624, 71],
#  [49, 354, 3400],
#  [35, 853, 95, 74, 1214, 4023],
#  [132, 1403, 236, 156, 1204, 121],
#  [46, 17432, 2685, 168, 684],
#  [235, 183, 573],
#  [10192, 208],
#  [3, 1535, 1483, 36],
#  [2, 2994, 490, 11338],
#  [40198, 4343, 21990],
#  [92, 2162, 8476],
#  [710, 177109, 5618, 101],
#  [2237, 436, 2568],
#  [3, 391, 2485, 649, 1366, 1518, 1366, 11410, 1331, 3481, 735, 631],
#  [375, 15316, 1351, 5256, 296, 321],
#  [11, 570, 37, 2352, 157, 15172, 9271, 19821, 572, 3223],
#  [735, 1971, 572, 9],
#  [1729, 8215, 10953],
#  [8, 126, 5],
#  [29, 196, 678, 17579, 19976, 772, 13666, 13667, 12, 3227, 4, 1395],
#  [198, 228, 1508, 159, 222, 58, 2393, 2068, 70, 315],
#  [369, 418, 1773],
#  [1055, 181, 3195, 69, 120, 653, 239, 788, 1097, 140, 4989, 788],
#  [360, 103, 8002, 323, 1640, 783, 24269, 1565, 1640],
#  [30, 6, 2943, 1989, 507],
#  [47, 106, 793, 14, 24],
#  [176, 224, 1141, 246, 4507, 762],
#  [2677, 1447, 1478, 442, 2097, 448, 367, 73, 22, 292, 833, 2097],
#  [13, 116, 22, 341, 930, 181],
#  [46453, 102, 26, 13, 22355],
#  [2, 234, 518, 990, 2543, 80, 51, 9, 1288, 30336],
#  [2260, 277, 282, 33669, 50984, 1203],
#  [269, 2023, 411, 80, 71],
#  [17, 7, 122, 927, 2494],
#  [483, 927, 35, 6955],
#  [966, 40, 32, 7339],
#  [7145, 2612, 13, 3539, 950, 408, 213, 362],
#  [337, 9783, 74, 1940, 3587, 1679, 52],
#  [9, 57, 747, 955, 10028],
#  [735, 36003, 95460, 432, 1353],
#  [6638, 559, 544, 3442],
#  [8, 4, 3049, 85, 424, 21564],
#  [339, 784, 74, 93],
#  [318, 1752, 20958, 350, 9457, 3051, 2336, 47180, 5020, 47180],
#  [1544, 493, 2390, 6560],
#  [7306, 24, 233],
#  [6, 778, 2414, 65, 2144, 25591, 8060, 19053, 66654, 1347],
#  [14, 73, 189, 1692, 254, 311, 1026, 425, 263, 1551],
#  [23514, 2704, 516, 1, 3374, 8342, 937, 81, 579, 1744, 5923],
#  [2408, 297, 41, 1252, 3139, 765],
#  [250, 2011, 4838],
#  [23917, 226, 6, 574, 2120],
#  [3035, 1908, 240, 31],
#  [73, 983, 415, 212],
#  [1987, 577, 1852, 1612, 9062],
#  [2860, 2073, 88, 5274, 949],
#  [125, 156, 18, 15],
#  [124, 284, 1313, 507, 242, 9413, 10, 1802, 949, 1704],
#  [1218, 12934],
#  [1281, 31, 34616, 1241, 9, 562, 27529, 1241],
#  [6, 892, 36, 12065, 835, 2909, 122467],
#  [16, 1, 1385, 469, 234, 322, 3455, 1569],
#  [2, 1784, 100, 392, 817],
#  [50, 893, 4840, 1592, 4840, 349, 35, 6268, 116657],
#  [29, 533, 6609, 536, 1, 5846],
#  [85, 97, 1149, 4839, 141, 10043],
#  [99, 102, 121],
#  [314, 891, 4343, 832, 970],
#  [22870, 6052],
#  [142524, 13, 9],
#  [139, 324, 107],
#  [14, 1510, 6545, 276, 197, 2701, 165, 44, 8, 39, 1510],
#  [95, 226, 42886, 820, 3892],
#  [33, 9598, 613, 88, 40, 159],
#  [335, 1753, 223, 2082, 2452],
#  [57, 2313, 70, 61, 135, 793, 199, 76, 206, 170, 86],
#  [982,
#   5402,
#   1687,
#   335,
#   154,
#   345,
#   42,
#   4315,
#   4797,
#   3530,
#   6813,
#   3530,
#   63,
#   1918,
#   2644,
#   37,
#   2272,
#   202],
#  [87, 26, 120, 1051, 258],
#  [3, 1476, 36135, 876, 3543, 558, 3, 398, 2869, 1929, 2135, 87, 26, 84],
#  [2, 11, 1589, 1769, 3918, 882, 609],
#  [243, 477, 1936, 71, 4097, 171306],
#  [45, 14692, 7814, 60, 6442],
#  [2381, 520, 1784, 100, 3092, 1851, 16, 335, 6485, 10186, 16233, 588],
#  [540, 26, 184, 761, 182, 148, 66],
#  [641, 402, 279, 1473, 1551, 350, 64, 122, 2602, 13770, 2602],
#  [382, 666, 502, 382, 336, 9],
#  [6058, 183, 80, 577, 1651, 405, 1800],
#  [250,
#   105,
#   1517,
#   250,
#   307,
#   2264,
#   15664,
#   14,
#   8548,
#   332,
#   1059,
#   331,
#   33,
#   338,
#   1580,
#   7305,
#   58,
#   58,
#   938],
#  [96, 32, 41],
#  [26527, 176, 43],
#  [7, 30, 1101],
#  [793, 177, 35, 477],
#  [37, 3800, 101, 1787],
#  [3167, 730, 1614, 1433, 126],
#  [2781, 449, 997, 381],
#  [860, 259, 28957, 1930],
#  [3637, 72205, 332, 63, 120, 310],
#  [7949, 22, 169, 16584, 1722, 4313, 34237],
#  [2, 1715, 1154, 14452, 8931, 560],
#  [2105, 87, 671, 739, 10680, 1116, 2105, 26, 117, 999, 1116],
#  [821, 362, 53, 227, 8396, 2627, 296],
#  [3368, 877, 2191, 863, 94, 877],
#  [133, 916, 10196, 300],
#  [270, 1260, 88, 278, 549, 88, 12834, 24420, 954, 7, 178, 49, 202],
#  [15, 1774, 361, 805, 225],
#  [19, 410, 1035, 693, 2741, 894, 78],
#  [32, 5, 6382, 580, 26, 1539, 163, 539],
#  [204, 10960, 4814, 545, 55, 468, 186, 398, 1912, 715, 258],
#  [10269, 400, 248, 1081, 13418, 107],
#  [283, 482, 751, 3298, 303, 482, 2272, 1522, 60, 146, 933, 807],
#  [1456, 138, 495, 1343, 1858],
#  [2472, 19487, 68679, 2084, 2007, 2569, 1556],
#  [493, 2315, 108, 261, 2220],
#  [523, 1056, 1384, 1427],
#  [3, 241, 438, 361, 2446, 3675],
#  [1607, 1417, 1284, 84],
#  [937, 8750, 532, 7159, 1090, 724, 178, 2969],
#  [41, 945, 5, 602, 13595, 73, 1001],
#  [72, 67, 1216, 7, 67, 83, 54],
#  [36, 186, 947],
#  [1158, 511, 511, 46, 284, 38, 21, 415, 1735, 325, 380, 1802, 146, 2147],
#  [2, 4059, 5669, 266, 215],
#  [5805, 13, 1565],
#  [45, 10252, 4343, 706, 2234],
#  [6650, 2100, 141, 1736],
#  [4558, 609, 119, 301],
#  [41, 1062, 223, 1922, 4342, 199, 602, 8178, 125, 485],
#  [515, 31441, 924],
#  [860, 178, 2994],
#  [172, 3234, 64],
#  [110, 5232, 5954, 1425],
#  [91, 259, 596, 184, 2945, 1837, 484],
#  [3, 653, 29, 14903, 455],
#  [4725, 283, 482, 178],
#  [19, 48, 2591, 64, 572],
#  [314, 4360],
#  [2, 135, 1424, 3078, 617, 165, 392, 215],
#  [7262, 24, 15],
#  [543, 818, 655, 604],
#  [244, 168, 112, 19, 363, 406],
#  [91, 20993, 1208],
#  [16066, 744],
#  [865, 683, 461, 22697],
#  [284, 2136, 573, 5388, 60, 2193],
#  [141, 12259, 23],
#  [11, 130, 9299, 8315, 23937, 644],
#  [891, 50697, 4345, 656, 1389],
#  [715, 5402, 335, 24103, 4228, 18217, 4289, 26927, 599, 231, 2511],
#  [862, 954, 6492, 78498, 6231],
#  [1,
#   405,
#   6,
#   51,
#   1647,
#   107,
#   519,
#   38,
#   938,
#   393,
#   826,
#   380,
#   1104,
#   177,
#   18,
#   52,
#   773,
#   3145,
#   10,
#   840],
#  [209, 450],
#  [643, 2281, 15475, 5292, 3787, 3046, 5, 2281],
#  [6, 162, 446, 8825, 9685, 1133, 3956],
#  [16, 191, 504, 201, 945, 1450, 8, 2153],
#  [3583, 953, 46214, 64, 2948],
#  [3533, 5670, 7316, 33, 163, 13, 223, 25, 959],
#  [625, 4896, 162, 1554, 470, 616, 203, 625, 9227, 1927, 2948, 1554, 556, 1683],
#  [167, 1707, 77, 228, 10407, 879, 117, 129, 2604, 11, 7084, 9485],
#  [5858, 11061, 63, 246, 8136],
#  [253, 397, 2976, 22366],
#  [4, 173, 193, 322, 7, 5, 39, 121, 7, 32, 1367, 2200, 93],
#  [3480, 497, 61685],
#  [6581, 63, 1591, 1340, 1005, 1610, 1340, 1, 19349, 991],
#  [298, 1167, 2387],
#  [782, 4168, 2424, 2531],
#  [284, 88, 650, 235, 346],
#  [651, 25959, 528, 237, 76, 7605, 237, 466, 2108, 8296, 1158],
#  [27679, 1209],
#  [24508, 14147, 1641, 14147, 7, 1395],
#  [45, 1535, 767, 88, 3734, 88, 150, 107],
#  [86, 13619],
#  [561, 961, 2219],
#  [3, 241, 3913, 3913, 176888],
#  [291, 708, 336, 792, 8675, 689, 336, 3882],
#  [655, 849, 5036, 299, 1349, 3075, 3356, 12639, 325, 536],
#  [427, 692, 2146],
#  [723, 4],
#  [6, 2283, 23211, 165],
#  [19, 783, 772, 2316, 675, 633, 9914, 2991],
#  [4477, 1805, 177, 2226],
#  [3, 8, 906, 585, 8612, 4461],
#  [2873, 1459, 81, 1315, 177, 1210, 7, 334],
#  [58, 40, 8018, 1103, 1851, 306, 58, 593, 46, 3054, 43, 58, 2352, 7022, 4],
#  [50, 1, 71, 722, 146, 428, 235],
#  [1113, 8413, 11769, 5420, 1135, 253, 1943],
#  [558, 498, 406, 1161, 1755],
#  [13, 2712, 508, 77, 84],
#  [124,
#   5351,
#   11300,
#   101,
#   2178,
#   21987,
#   313,
#   5142,
#   4578,
#   440,
#   108,
#   18199,
#   1767,
#   352],
#  [1251, 19, 12, 932, 2430, 597, 48, 1781, 645, 152],
#  [543, 860, 153, 8036, 153, 2503, 402, 4887],
#  [6, 5665, 6543, 287],
#  [224, 201, 301, 5, 3439, 331, 2045, 1082, 353, 6819, 4, 225, 224],
#  [195, 380, 11258],
#  [91, 3220, 40],
#  [1175, 442, 981, 1179],
#  [2317, 140, 480, 469, 80],
#  [346, 190, 439, 146],
#  [287, 850, 247, 66],
#  [10220, 734, 1367, 291],
#  [2778,
#   1024,
#   18052,
#   35182,
#   19185,
#   1564,
#   652,
#   139,
#   65538,
#   18,
#   20786,
#   4703,
#   3690,
#   139,
#   94],
#  [1055, 181, 3078, 617, 13269],
#  [1515, 415, 6669, 548, 1, 355, 21, 499, 686, 10],
#  [137, 2021, 907, 3383],
#  [2, 36, 229, 9714],
#  [5860],
#  [174, 2906],
#  [7738, 5125, 385, 59, 121],
#  [515, 1225, 9],
#  [104, 4768, 67819, 30024],
#  [1, 584, 92, 3184, 1, 136],
#  [6, 2050, 985, 5, 20252, 4581, 13296],
#  [395],
#  [6569, 8771, 9910, 569, 6331],
#  [30, 1339, 6585, 796],
#  [3213, 1415, 7825],
#  [10614, 1300, 921, 32, 5, 2110, 362, 46, 92, 26847, 282, 27, 3011, 938],
#  [2052, 113, 64, 240, 7, 211, 575],
#  [315, 556, 4889, 890],
#  [1292, 11, 19093, 295, 463],
#  [2319, 3662],
#  [2175, 779, 5548],
#  [7731, 9929, 1839, 273],
#  [1390,
#   3936,
#   11484,
#   1448,
#   95,
#   11484,
#   240,
#   36349,
#   1554,
#   3,
#   534,
#   12471,
#   5900,
#   5,
#   83],
#  [],
#  [369, 363, 78, 617, 825, 2571, 2173, 2872, 115676, 583],
#  [5095, 1202, 2014, 104, 1449],
#  [311, 149, 11506],
#  [367, 5995, 630, 455, 158, 1117, 1761],
#  [173, 32, 17, 59, 757, 1350, 136, 831, 34, 444],
#  [1053,
#   2768,
#   176,
#   1576,
#   3,
#   16467,
#   19,
#   309,
#   2802,
#   5,
#   246,
#   148,
#   450,
#   137,
#   966,
#   887,
#   63,
#   3347,
#   1605,
#   7513],
#  [366, 6671, 732, 353, 640],
#  [17,
#   1940,
#   9642,
#   39010,
#   5132,
#   1624,
#   15631,
#   71,
#   5159,
#   1173,
#   654,
#   1624,
#   5047,
#   134,
#   17,
#   337,
#   66200,
#   115],
#  [2, 2537, 925, 7, 379],
#  [153943, 2855, 916, 3, 2931, 290, 7064],
#  [1027, 270, 15679, 18516, 6474],
#  [26096, 52353, 3121, 4357],
#  [142, 39, 625, 1285, 6002, 7425, 1240],
#  [5313, 711, 1010, 1811],
#  [277, 2309, 1195, 12357, 18203, 849, 23750, 987, 1633, 113, 18203],
#  [27891, 615, 366, 23339, 474],
#  [839, 14072, 3430, 972, 1217, 174, 36],
#  [17, 69, 5, 5547, 885, 289, 136],
#  [525, 1265, 496, 733, 704, 8633, 7280],
#  [40, 6302, 91],
#  [18621, 765, 897, 1808, 3911, 138, 42, 335, 933],
#  [5918, 35, 4658, 23218],
#  [3, 115, 31, 105, 2801, 323, 18976],
#  [594, 821, 941, 218, 3, 587, 154, 134],
#  [409, 503, 3550, 609, 601, 464],
#  [172, 1946, 6737, 172, 350, 5190, 798, 15537, 1946, 350],
#  [69014, 4433, 24669, 7346],
#  [608, 160, 8062, 1827, 167, 142, 2133, 100],
#  [67, 121],
#  [17580, 932, 10322, 12383, 1068, 1143, 12],
#  [2, 529, 109, 3686, 5959],
#  [115, 166, 230, 111],
#  [170, 579, 15698, 2897, 3550, 2263],
#  [26912, 3426],
#  [1988, 457, 41, 551, 2340, 666],
#  [],
#  [45, 110, 1204],
#  [19, 623, 3444, 3269, 1628, 8373, 3589, 35848],
#  [1496, 103, 9836, 4008, 830, 117],
#  [27, 14735, 57, 636, 86, 4126],
#  [2, 638, 11, 621, 545, 2891],
#  [21700, 480, 554, 329, 855],
#  [37, 2746, 2495, 4433, 14891, 3675, 10332],
#  [465, 1964, 832, 970, 1449, 1561, 45],
#  [1605, 55, 747, 5365],
#  [2301, 3141, 636, 51],
#  [17163, 470, 273, 682, 1831, 8679, 55, 61, 1098],
#  [827, 481, 335],
#  [1146, 42659, 5528, 402],
#  [50, 34, 20, 94],
#  [257, 31995],
#  [242, 20, 1144, 2105, 1572, 6576],
#  [1289, 10, 258, 199, 416, 13, 59],
#  [622, 148, 15084],
#  [1033, 267, 40703, 210],
#  [3, 59, 1109, 152, 117, 89, 878],
#  [215, 26, 1930],
#  [2954, 582, 7, 10, 1, 6140, 475, 714],
#  [115, 148, 540, 27339, 26],
#  [377,
#   253,
#   3830,
#   1299,
#   14300,
#   2607,
#   1644,
#   2337,
#   485,
#   211,
#   11,
#   3858,
#   23967,
#   602],
#  [2732, 4, 563],
#  [2, 630, 101, 3223, 364],
#  [2646, 1396, 91, 1972],
#  [483, 12086, 11, 3656],
#  [2136, 289, 301, 116],
#  [680, 577, 15397, 1245, 769, 24517, 618, 779, 2212, 254, 1916, 390],
#  [4483, 7, 48, 2609, 144755, 55399, 31120, 3082, 16537, 1600, 867, 2246],
#  [632, 156, 562, 24, 59, 127, 24, 83, 2409, 36],
#  [2830, 9826],
#  [18240, 2257, 4587],
#  [1602, 332, 5, 57093],
#  [7580, 28813, 228, 4213, 1788],
#  [195, 3857, 3667, 693, 224, 10511, 2581, 154660, 535, 7798, 5334],
#  [4470, 4423, 1, 540, 464, 22, 10, 842, 464],
#  [212, 42, 145, 5, 29, 151352, 296, 512],
#  [2, 31, 100, 5835, 237, 600],
#  [73, 12, 3, 22, 1008, 286, 442, 9165, 213, 82, 179, 9327],
#  [800, 178, 2119, 79, 794, 57249, 16615],
#  [9001, 352, 108, 26612, 871, 7660],
#  [633, 18, 70, 5005, 14727, 2145],
#  [2, 402, 180, 4007, 3726],
#  [1751, 6, 449, 4],
#  [452, 58, 324, 2380, 13, 1728, 183],
#  [2954, 4465, 1148, 129, 168, 25, 4328],
#  [6422, 3551, 147],
#  [575, 70494, 141733, 35, 1067],
#  [50, 4083, 1891, 2357, 4112, 2346, 338, 23441],
#  [14, 10, 98, 109, 364, 2455, 319],
#  [1141, 149612, 2, 13876, 1978, 9129],
#  [20, 36, 4988, 852, 94],
#  [387, 782, 133, 1274],
#  [9258, 2288, 1274],
#  [354, 493, 29, 214, 9965],
#  [14, 1525, 8, 6753, 1922, 364],
#  [373,
#   47,
#   1205,
#   630,
#   6568,
#   2305,
#   10145,
#   1375,
#   103281,
#   1054,
#   382,
#   740,
#   131,
#   514,
#   9686,
#   47,
#   1054,
#   519,
#   1178],
#  [9, 620, 1267, 4],
#  [2, 3586, 7186],
#  [18660, 2247, 89, 878],
#  [2777, 40, 3190, 58, 1745, 1207, 131, 1025],
#  [42, 1461, 95, 4, 952],
#  [11128, 8155, 231],
#  [31, 1052, 986, 2224, 423, 1187, 23, 345, 2080, 1143],
#  [15363, 4213, 273],
#  [18111, 13127, 60, 1058, 16448, 1374, 925],
#  [85,
#   14,
#   746,
#   1560,
#   99,
#   410,
#   1379,
#   1,
#   1824,
#   26,
#   76,
#   492,
#   2061,
#   4757,
#   5122,
#   202],
#  [1732, 2042, 961, 3437, 37, 161, 749, 284, 136],
#  [2, 36, 357, 346, 298, 4817, 275, 6587],
#  [487, 11, 78, 31926],
#  [1292, 11, 8, 62, 129, 1301],
#  [410, 1379, 297, 84, 12],
#  [142, 433, 267, 5813, 51, 2924, 101],
#  [52518, 1807],
#  [49, 51489, 29823, 2086],
#  [45, 161, 1695, 4977],
#  [521, 305, 7754, 24, 444, 27, 655, 93],
#  [2, 4451, 100],
#  [104, 530, 845, 468],
#  [784, 41, 22324, 83, 91, 28],
#  [219, 53, 3696, 429],
#  [204, 278, 1061, 524, 179, 599],
#  [23, 1583, 4711, 6888, 603, 1902],
#  [2385,
#   291,
#   200,
#   385,
#   12692,
#   136,
#   1320,
#   976,
#   4,
#   976,
#   723,
#   291,
#   3784,
#   4,
#   976,
#   315,
#   64],
#  [400, 506, 5926, 507],
#  [246, 279, 278, 65, 1976, 165],
#  [21932, 85, 198, 2041, 3482, 174],
#  [3812, 4649],
#  [1429, 2952, 174, 128, 3041],
#  [1, 544, 3545, 1026, 237],
#  [891, 682, 764],
#  [561, 304, 47, 858],
#  [15, 533, 5536],
#  [4246, 99, 8, 32, 3049],
#  [1751, 38799],
#  [1826, 727, 204, 7653, 2623],
#  [13, 3076, 7409, 15],
#  [1601, 1601, 1451, 646, 456, 5569, 4756, 456, 32949, 43],
#  [2, 36, 72, 1464, 322, 101],
#  [291, 59, 7400, 717, 156, 255, 289, 723],
#  [3413, 1589, 5341, 10, 74, 29, 339, 1, 2242, 25],
#  [272, 1164, 176, 3380, 990, 20384],
#  [3, 5716, 1967, 26060, 959],
#  [249, 6596, 18443, 8949, 107, 6807, 134, 840, 727, 12803],
#  [175, 5440, 113, 4, 13326, 963],
#  [5847, 1104],
#  [24, 870, 57, 158],
#  [130, 2652, 1543, 129],
#  [195, 264, 5883, 1381, 3367],
#  [6876, 12098, 3222, 394],
#  [3394, 35, 271, 1, 48, 35, 5450, 1583],
#  [91, 2307],
#  [1753, 4162, 11628, 442, 57324, 442, 962, 138, 1365],
#  [254, 251, 84, 953, 2608, 1742, 441, 5242, 36],
#  [4, 59, 319, 8623, 2572, 8623, 255, 305],
#  [2777, 44, 4597, 6268],
#  [4928, 588, 402],
#  [76, 9283, 421, 822, 1455, 743, 611, 5639, 79, 439, 283, 166],
#  [677, 442, 286, 12, 91, 12, 8856, 288, 1088, 12, 1534],
#  [244, 573, 116, 1398, 52, 21],
#  [27, 315, 1535, 2316, 94, 8006, 550, 10883, 3905],
#  [836, 41, 1919, 552, 41],
#  [129, 351, 3588, 131],
#  [91, 147],
#  [2092, 17, 1689, 300],
#  [2486, 324, 4827, 35, 8298, 78, 92, 28],
#  [39, 268, 65, 151, 14048, 1608],
#  [695, 498, 1633, 207, 21, 1269],
#  [17,
#   8568,
#   1201,
#   21006,
#   62,
#   749,
#   4968,
#   1017,
#   49412,
#   2881,
#   363,
#   922,
#   749,
#   62,
#   135,
#   652,
#   3917,
#   513],
#  [63, 964, 96, 15, 22143, 4627, 20580],
#  [768, 1105, 169960, 2779],
#  [1550, 1194, 324, 4256, 2829],
#  [2, 4684, 184, 1616],
#  [138, 288, 11356, 1694, 606],
#  [3997, 1256, 36, 16313, 15911, 13205, 40491],
#  [688, 1971, 9634, 21532, 3217, 3673, 926],
#  [567, 107, 11165, 145, 9, 38],
#  [20, 17, 4593, 5, 68, 7059, 56],
#  [7, 70, 787, 1415, 2419, 956],
#  [77, 4, 2355],
#  [56, 99],
#  [1, 2056, 6484, 2861, 292, 364, 88, 3222, 3481],
#  [6080, 1238, 218, 44, 2407, 1445, 358],
#  [2, 11, 3133, 750, 2254],
#  [2, 11, 1, 3401, 10914],
#  [462, 3, 70, 3670, 460, 3875, 24, 262, 1261, 10, 1, 502, 71],
#  [1, 4644, 1, 1523, 10843],
#  [1111, 1610, 31],
#  [405, 219, 53, 1014, 51],
#  [14251, 2580, 2933],
#  [14, 10, 10239, 734, 8867, 7521, 448, 29, 1695, 330, 48501],
#  [711, 34708],
#  [50, 388, 7989, 10309, 1314, 18549],
#  [278, 1061],
#  [7397, 69, 6, 541, 838, 943],
#  [1662, 17, 1035, 147],
#  [775, 2135, 4401, 148, 3936, 456, 6, 452, 2469, 227],
#  [667, 3959, 320, 7623, 636, 10698],
#  [594, 12, 1497, 28],
#  [9450, 519, 5258, 5571, 1734, 25504, 3, 502, 964, 8763, 865, 4141, 2182, 654],
#  [27, 1693, 5, 1192, 5, 1656, 716, 258],
#  [1764, 17995],
#  [13932, 34850, 92916],
#  [19778, 488],
#  [160, 196, 3625, 343, 6, 90, 11],
#  [5026, 53, 854, 293, 28],
#  [6, 1695],
#  [200, 99, 2255, 4955, 1309, 152373, 5732],
#  [1015, 4448],
#  [54, 6, 2027, 54, 6090, 231],
#  [1026, 854, 2209, 395, 1026, 854, 126],
#  [504, 7873, 397, 1866, 1523],
#  [29, 694, 200, 1470],
#  [16170, 4333, 12707, 1836, 28800, 3609, 830, 121],
#  [104, 213, 11200, 4081],
#  [1, 62, 4396, 2852, 1629, 147],
#  [571, 953, 391, 572, 1950],
#  [18, 1982, 158, 2714, 2, 9779, 9138, 2714],
#  [44, 1059, 704, 740, 205, 134, 186, 958],
#  [1911, 700, 1401, 1451, 1397, 670, 67, 83, 66],
#  [2, 1645, 5928, 429, 20],
#  [48, 1841, 425, 111],
#  [209,
#   120,
#   629,
#   1262,
#   120,
#   1,
#   9856,
#   2647,
#   283,
#   482,
#   47,
#   97,
#   5,
#   915,
#   3,
#   67,
#   4156,
#   136],
#  [45, 6810],
#  [39, 594, 12, 62, 2986, 80, 1701, 19880, 368, 4354],
#  [162, 980, 207, 2377, 89, 878],
#  [817, 314, 18633],
#  [1408, 1, 2, 56, 211, 55, 5, 3317, 8, 182, 41, 410, 297, 223, 83],
#  [3402, 356, 1107, 4042, 158],
#  [1492, 89, 3488, 161, 3008, 1063, 620, 457, 23, 562, 1788],
#  [279, 16760, 2047, 333, 219, 1146, 208],
#  [588, 2762, 516, 6589, 450, 5923, 1459, 1446, 1897, 945, 1506, 35, 2762],
#  [159, 4, 10706, 2560, 140, 17, 20, 3, 1500],
#  [25810, 169, 179],
#  [3, 989, 2053, 13047, 206],
#  [164, 12427, 1077, 3167, 730, 2315, 3296],
#  [143, 1370, 1352, 692, 1517, 12927, 1517, 11022, 6038, 7622],
#  [19, 2269, 9339, 292],
#  [543, 243, 4486, 477, 11121],
#  [165, 216, 5039, 21, 97, 5],
#  [103, 1411],
#  [61, 98, 485, 1084, 470, 13, 11710, 4492],
#  [1472, 2262, 147, 35, 74, 151, 1200, 1488],
#  [16, 16724, 189, 6630],
#  [1270, 704, 182, 705, 1267, 607],
#  [173],
#  [2233, 10877, 239, 5056, 1805, 1805, 2233, 10877, 345, 1805],
#  [7, 24, 7176, 1174, 2534],
#  [11641, 104, 3060],
#  [3608, 2954, 405, 851, 2193],
#  [3,
#   32,
#   615,
#   655,
#   14,
#   10,
#   840,
#   5,
#   10,
#   2324,
#   437,
#   130,
#   1075,
#   97,
#   410,
#   224,
#   158,
#   459,
#   1903],
#  [8477, 1039, 3355, 60],
#  [1634, 3763, 22944, 3685],
#  [407, 1602, 493],
#  [1209, 84, 67, 632, 355, 73, 17, 67],
#  [354, 360, 15777, 1223, 11775, 1408, 20852, 5752, 8463],
#  [14, 194, 7548, 10322, 37, 241, 741, 17580, 61009, 5212],
#  [33, 5731],
#  [1726,
#   150,
#   2687,
#   685,
#   4323,
#   71,
#   190,
#   1703,
#   494,
#   2321,
#   5230,
#   78,
#   114,
#   5372,
#   246,
#   779,
#   227],
#  [6, 152, 271, 1324, 78, 2765],
#  [1284, 3951, 2107, 19, 73, 12],
#  [150, 155, 575, 270, 858],
#  [37, 873, 1421, 2454, 7, 842, 509, 94, 559, 483, 1782, 55, 3, 28],
#  [523, 107, 826, 430, 116, 1020, 84, 55, 13148, 1548, 1159, 1281, 1542],
#  [638, 3713, 5237, 1607],
#  [27, 1591, 3976, 121],
#  [171, 526, 6079, 101],
#  [44, 19794, 19, 3614, 177, 406],
#  [2214, 72, 509, 94, 1796, 19, 42, 42, 15],
#  [876, 3809, 39417, 3825, 1169, 978, 876, 5, 3308, 450, 986, 6506, 176],
#  [333, 263, 84, 107],
#  [188, 80, 51, 411, 80],
#  [43127, 2559],
#  [1251, 1129, 194, 32232, 50421],
#  [877, 56, 663],
#  [1, 584, 7015],
#  [766, 608, 640, 465],
#  [291, 1896, 1306, 55, 1722, 34, 28],
#  [104, 26145, 87],
#  [409, 901, 423, 6636, 235, 2519, 209, 3037, 320, 2169, 212, 221, 394],
#  [3, 7079, 439, 2762, 1106, 5626, 581, 215, 2381, 520],
#  [451, 5, 2437, 945, 694],
#  [27, 1023, 9459, 38741, 184, 515],
#  [360, 7, 42, 503, 288, 146],
#  [285, 3805, 745],
#  [7237, 252, 103, 568, 5611],
#  [7, 2215, 98693, 6124],
#  [46, 40, 175, 253, 222, 123, 58],
#  [10927, 34, 516, 97, 2, 2100, 275, 2088, 2205, 202],
#  [399, 17, 485, 293, 527, 64, 34, 76, 34, 59, 1430, 68, 115],
#  [11859, 11768, 23, 2303],
#  [170, 6838, 6, 10, 74, 285, 431],
#  [973, 1427, 1585],
#  [16, 475, 1199, 1, 7093, 10, 54, 699, 1059],
#  [3806, 86, 2043, 247, 730, 1696, 15],
#  [73, 127, 402, 527, 57, 12],
#  [164, 860, 452, 25],
#  [5, 1617, 14422, 71],
#  [8, 3444, 1557],
#  [152, 725, 6281],
#  [4, 984, 408, 2600, 8388, 84, 150],
#  [1, 466, 832, 265, 706, 892, 165, 215],
#  [753, 13, 608, 171],
#  [3, 47, 917, 6345, 2664, 6062, 4647],
#  [115, 7, 73, 28271, 20404, 532],
#  [64, 122, 25327],
#  [1074, 44634],
#  [6, 152, 115345, 280, 11121, 1851, 112],
#  [143,
#   3119,
#   457,
#   214,
#   1726,
#   6779,
#   1804,
#   3,
#   134625,
#   6204,
#   281,
#   1804,
#   13385,
#   1804,
#   1526],
#  [13371, 24, 356, 1602, 1, 25],
#  [54, 316, 3516, 41, 316, 43, 67, 41, 316],
#  [3212, 36079, 527, 669, 205, 208, 103, 2369, 5360, 147, 9258],
#  ...]

# %%
test_matrix = sequence.pad_sequences(seq_test, maxlen=max_len)
test_matrix.shape
# Out:
# (326531, 29)

# %%
vocab_len ###NUMBER PF UNIQUE WORDS IN THE DATA
# Out:
# 181603

# %% [markdown]
# # DEFINING MODEL ARCHITECTURE

# %%
model_lstm = Sequential()
model_lstm.add(Embedding(vocab_len+1, 200, input_length=max_len))
model_lstm.add(Dropout(0.2))
model_lstm.add(LSTM(100 , activation='relu'))
model_lstm.add(Dropout(0.2))
model_lstm.add(Dense(1, activation="sigmoid"))
model_lstm.compile(loss="binary_crossentropy", optimizer="adam",metrics=['accuracy'])

model_lstm.summary()

model_lstm.fit(train_matrix,y_train.values , batch_size=1000 ,verbose=2, epochs = 2 , validation_split=0.3)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 29, 200)           36320800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 29, 200)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               120400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 36,441,301
# Trainable params: 36,441,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 685713 samples, validate on 293878 samples
# Epoch 1/2
#  - 836s - loss: 0.1450 - accuracy: 0.9459 - val_loss: 0.1205 - val_accuracy: 0.9515
# Epoch 2/2
#  - 965s - loss: 0.1084 - accuracy: 0.9559 - val_loss: 0.1211 - val_accuracy: 0.9530

# %%
pred_lstm = model_lstm.predict(test_matrix)
prediction_lstm = roc_auc_score(y_test,pred_lstm)
prediction_lstm
# Out:
# 0.9487366408172323

# %%
model_cnn_lstm = Sequential()
model_cnn_lstm.add(Embedding(vocab_len+1, 200, input_length=max_len))
model_cnn_lstm.add(Dropout(0.2))
model_cnn_lstm.add(Conv1D(64,5,activation="relu"))
model_cnn_lstm.add(MaxPooling1D(pool_size=4))
model_cnn_lstm.add(Dropout(0.2))
model_cnn_lstm.add(LSTM(100 , activation='relu'))
model_cnn_lstm.add(Dropout(0.2))
model_cnn_lstm.add(Dense(1, activation="sigmoid"))
model_cnn_lstm.compile(loss="binary_crossentropy", optimizer="adam",metrics=['accuracy'])
model_cnn_lstm.summary()
model_cnn_lstm.fit(train_matrix,y_train.values , batch_size=1000 ,verbose=2, epochs = 2 , validation_split=0.3)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 29, 200)           36320800
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 29, 200)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 25, 64)            64064
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 6, 64)             0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 6, 64)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               66000
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 36,450,965
# Trainable params: 36,450,965
# Non-trainable params: 0
# _________________________________________________________________
# Train on 685713 samples, validate on 293878 samples
# Epoch 1/2
#  - 675s - loss: 0.1522 - accuracy: 0.9463 - val_loss: 0.1292 - val_accuracy: 0.9491
# Epoch 2/2
#  - 672s - loss: 0.1175 - accuracy: 0.9531 - val_loss: 0.1287 - val_accuracy: 0.9498

# %%
pred_cnn_lstm = model_cnn_lstm.predict(test_matrix)
prediction_cnn_lstm = roc_auc_score(y_test,pred_cnn_lstm)
prediction_cnn_lstm
# Out:
# 0.9357573720156617

# %%
model_gru = Sequential()
model_gru.add(Embedding(vocab_len+1, 200, input_length=max_len))
model_gru.add(Dropout(0.2))
model_gru.add(GRU(100 , activation='relu'))
model_gru.add(Dropout(0.2))
model_gru.add(Dense(1, activation="sigmoid"))
model_gru.compile(loss="binary_crossentropy", optimizer="adam",metrics=['accuracy'])

model_gru.summary()

model_gru.fit(train_matrix,y_train.values , batch_size=1000 ,verbose=2, epochs = 2 , validation_split=0.3)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 29, 200)           36320800
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 29, 200)           0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 100)               90300
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 36,411,201
# Trainable params: 36,411,201
# Non-trainable params: 0
# _________________________________________________________________
# Train on 685713 samples, validate on 293878 samples
# Epoch 1/2
#  - 811s - loss: 0.1513 - accuracy: 0.9443 - val_loss: 0.1206 - val_accuracy: 0.9515
# Epoch 2/2
#  - 797s - loss: 0.1094 - accuracy: 0.9553 - val_loss: 0.1199 - val_accuracy: 0.9517

# %%
pred_gru = model_gru.predict(test_matrix)
prediction_gru = roc_auc_score(y_test,pred_gru)
prediction_gru
# Out:
# 0.9484868821660196

# %% [markdown]
# ### IMPPORTING PRE-TRAINED EMBEDDING LAYER

# %%
embeddings_index = dict()
f = open(r"C:\Users\91876\Desktop\Poonam\Python_Project_3\glove.6B.200d.txt" , encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
embedding_matrix = np.zeros((vocab_len + 1, 200))
for word, index in tok.word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[index] = embedding_vector

# %%
embedding_matrix.shape
# Out:
# (181604, 200)

# %% [markdown]
# ### DEFINING MODEL ARCHITECTURE WITH EMBEDDING LAYER

# %%
model_lstm_emb = Sequential()
model_lstm_emb.add(Embedding(vocab_len+1, 200, input_length=max_len , weights=[embedding_matrix], trainable=False))
model_lstm_emb.add(Dropout(0.2))
model_lstm_emb.add(LSTM(100 , activation='relu'))
model_lstm_emb.add(Dropout(0.2))
model_lstm_emb.add(Dense(1, activation="sigmoid"))
model_lstm_emb.compile(loss="binary_crossentropy", optimizer="adam",metrics=['accuracy'])

model_lstm_emb.summary()

model_lstm_emb.fit(train_matrix,y_train.values , batch_size=1000 ,verbose=2, epochs = 2 , validation_split=0.3)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 29, 200)           36320800
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 29, 200)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 100)               120400
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 36,441,301
# Trainable params: 120,501
# Non-trainable params: 36,320,800
# _________________________________________________________________
# Train on 685713 samples, validate on 293878 samples
# Epoch 1/2
#  - 462s - loss: 0.1599 - accuracy: 0.9422 - val_loss: 0.1313 - val_accuracy: 0.9489
# Epoch 2/2
#  - 444s - loss: 0.1275 - accuracy: 0.9509 - val_loss: 0.1221 - val_accuracy: 0.9521

# %%
pred_lstm_emb= model_lstm_emb.predict(test_matrix)
prediction_lstm_emb = roc_auc_score(y_test,pred_lstm_emb)
prediction_lstm_emb
# Out:
# 0.9437698911666703

# %%
model_cnn_lstm_emb = Sequential()
model_cnn_lstm_emb.add(Embedding(vocab_len+1, 200, input_length=max_len , weights=[embedding_matrix], trainable=False))
model_cnn_lstm_emb.add(Dropout(0.2))
model_cnn_lstm_emb.add(Conv1D(64,5,activation="relu"))
model_cnn_lstm_emb.add(MaxPooling1D(pool_size=4))
model_cnn_lstm_emb.add(Dropout(0.2))
model_cnn_lstm_emb.add(LSTM(100 , activation='relu'))
model_cnn_lstm_emb.add(Dropout(0.2))
model_cnn_lstm_emb.add(Dense(1, activation="sigmoid"))
model_cnn_lstm_emb.compile(loss="binary_crossentropy", optimizer="adam",metrics=['accuracy'])
model_cnn_lstm_emb.summary()
model_cnn_lstm_emb.fit(train_matrix,y_train.values , batch_size=1000 ,verbose=2, epochs = 2 , validation_split=0.3)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 29, 200)           36320800
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 29, 200)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 25, 64)            64064
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 6, 64)             0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 6, 64)             0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 100)               66000
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 36,450,965
# Trainable params: 130,165
# Non-trainable params: 36,320,800
# _________________________________________________________________
# Train on 685713 samples, validate on 293878 samples
# Epoch 1/2
#  - 239s - loss: 0.1637 - accuracy: 0.9432 - val_loss: 0.1381 - val_accuracy: 0.9476
# Epoch 2/2
#  - 213s - loss: 0.1394 - accuracy: 0.9476 - val_loss: 0.1356 - val_accuracy: 0.9482

# %%
pred_model_cnn_lstm_emb = model_cnn_lstm_emb.predict(test_matrix)
prediction_model_cnn_lstm_emb = roc_auc_score(y_test,pred_model_cnn_lstm_emb )
prediction_model_cnn_lstm_emb
# Out:
# 0.9270292115193229

# %%
model_gru_emb = Sequential()
model_gru_emb.add(Embedding(vocab_len+1, 200, input_length=max_len , weights=[embedding_matrix], trainable=False))
model_gru_emb.add(Dropout(0.2))
model_gru_emb.add(GRU(100 , activation='relu'))
model_gru_emb.add(Dropout(0.2))
model_gru_emb.add(Dense(1, activation="sigmoid"))
model_gru_emb.compile(loss="binary_crossentropy", optimizer="adam",metrics=['accuracy'])

model_gru_emb.summary()

model_gru_emb.fit(train_matrix,y_train.values , batch_size=1000 ,verbose=2, epochs = 2 , validation_split=0.3)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 29, 200)           36320800
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 29, 200)           0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 100)               90300
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 36,411,201
# Trainable params: 90,401
# Non-trainable params: 36,320,800
# _________________________________________________________________
# Train on 685713 samples, validate on 293878 samples
# Epoch 1/2
#  - 316s - loss: 0.1580 - accuracy: 0.9422 - val_loss: 0.1271 - val_accuracy: 0.9505
# Epoch 2/2
#  - 310s - loss: 0.1261 - accuracy: 0.9511 - val_loss: 0.1211 - val_accuracy: 0.9527

# %%
pred_gru_emb = model_gru_emb.predict(test_matrix)
prediction_gru_emb = roc_auc_score(y_test,pred_gru_emb)
prediction_gru_emb
# Out:
# 0.9447059996813079

# %% [markdown]
# #### MODEL PERFORMANCE

# %%
predictions={"MODELS":["LSTM","EMB_LSTM","CNN_LSTM","EMB_CNN_LSTM","GRU","EMB_GRU"], "AUC_SCORE":[prediction_lstm, prediction_lstm_emb,prediction_cnn_lstm,prediction_model_cnn_lstm_emb,prediction_gru,prediction_gru_emb]}
Predictions = pd.DataFrame(predictions)
Predictions
# Out:
#          MODELS  AUC_SCORE
# 0          LSTM   0.948737
# 1      EMB_LSTM   0.943770
# 2      CNN_LSTM   0.935757
# 3  EMB_CNN_LSTM   0.927029
# 4           GRU   0.948487
# 5       EMB_GRU   0.944706

# %% [markdown]
# ###### EMBEDDING LAYER REDUCED THE TRAINING TIME WITH SIMILAR ACCURACY

# %% [markdown]
# ### SAVING THE MODEL AND WEIGHT FILE

# %%
model_lstm_json = model_lstm.to_json()
with open ("model_lstm_json.json","w")as json_file:
    json_file.write(model_lstm_json)
model_lstm.save_weights("model_lstm.h5")

# %%
model_lstm_emb_json = model_lstm_emb.to_json()
with open ("model_lstm_emb_json.json","w")as json_file:
    json_file.write(model_lstm_emb_json)
model_lstm_emb.save_weights("model_lstm_emb.h5")

# %%
model_cnn_lstm_json = model_cnn_lstm.to_json()
with open ("model_cnn_lstm_json.json","w")as json_file:
    json_file.write(model_cnn_lstm_json)
model_cnn_lstm.save_weights("model_cnn_lstm.h5")

# %%
model_cnn_lstm_json = model_cnn_lstm.to_json()
with open ("model_cnn_lstm_json.json","w")as json_file:
    json_file.write(model_cnn_lstm_json)
model_cnn_lstm.save_weights("model_cnn_lstm.h5")

# %%
model_cnn_lstm_emb_json = model_cnn_lstm_emb.to_json()
with open ("model_cnn_lstm_emb_json.json","w")as json_file:
    json_file.write(model_cnn_lstm_emb_json)
model_cnn_lstm_emb.save_weights("model_cnn_lstm_emb.h5")

# %%
model_gru_json = model_gru.to_json()
with open ("model_gru_json.json","w")as json_file:
    json_file.write(model_gru_json)
model_gru.save_weights("model_gru.h5")

# %%
model_gru_emb_json = model_gru_emb.to_json()
with open ("model_gru_emb_json.json","w")as json_file:
    json_file.write(model_gru_emb_json)
model_gru_emb.save_weights("model_gru_emb.h5")
